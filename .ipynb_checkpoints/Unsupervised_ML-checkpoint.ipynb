# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.base import TransformerMixin
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import tensorflow as tf
import re

# %%
# Import cleaned VAERS dataset (for full marks next week, use API call to aws database with csv)
vaers_df = pd.read_csv('vaers_data_cleaned.csv', low_memory=False)
print(vaers_df.shape)
vaers_df.head(5)
# Out:
# (40247, 49)
#    vaers_id    recvdate state_  age_yrs  cage_yr sex  \
# 0   1000000  02/04/2021     CA      NaN      NaN   M
# 1   1000001  02/04/2021     WI      NaN      NaN   F
# 2   1000003  02/04/2021     PA     29.0      NaN   F
# 3   1000006  02/04/2021    NaN      NaN      NaN   F
# 4   1000007  02/04/2021     WI     53.0      NaN   M
#
#                                         symptom_text died datedied l_threat  \
# 0  tested positive; tested positive; This is a sp...  NaN      NaN      NaN
# 1  covid symptoms the 28th and tested positive; c...  NaN      NaN      NaN
# 2  rash and hives all over body; rash and hives a...  NaN      NaN      NaN
# 3  tested positive for covid; tested positive for...  NaN      NaN      NaN
# 4  blood sugar has been out of control ranging fr...  NaN      NaN      NaN
#
#    ... symptomversion4 symptom5  symptomversion5 vax_type         vax_manu  \
# 0  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 1  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 2  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 3  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 4  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
#
#   vax_lot vax_dose_series vax_route  vax_site  \
# 0     NaN               1       NaN       NaN
# 1     NaN               1       NaN       NaN
# 2  EJ1685               1        OT        LA
# 3     NaN               1       NaN       NaN
# 4     NaN               1       NaN        RA
#
#                               vax_name
# 0  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4  COVID19 (COVID19 (PFIZER-BIONTECH))
#
# [5 rows x 49 columns]

# %%
# Drop duplicates in the dataframe
vaers_df.drop_duplicates(inplace=True)
print(vaers_df.shape)
vaers_df.head(5)
# Out:
# (40209, 49)
#    vaers_id    recvdate state_  age_yrs  cage_yr sex  \
# 0   1000000  02/04/2021     CA      NaN      NaN   M
# 1   1000001  02/04/2021     WI      NaN      NaN   F
# 2   1000003  02/04/2021     PA     29.0      NaN   F
# 3   1000006  02/04/2021    NaN      NaN      NaN   F
# 4   1000007  02/04/2021     WI     53.0      NaN   M
#
#                                         symptom_text died datedied l_threat  \
# 0  tested positive; tested positive; This is a sp...  NaN      NaN      NaN
# 1  covid symptoms the 28th and tested positive; c...  NaN      NaN      NaN
# 2  rash and hives all over body; rash and hives a...  NaN      NaN      NaN
# 3  tested positive for covid; tested positive for...  NaN      NaN      NaN
# 4  blood sugar has been out of control ranging fr...  NaN      NaN      NaN
#
#    ... symptomversion4 symptom5  symptomversion5 vax_type         vax_manu  \
# 0  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 1  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 2  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 3  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
# 4  ...             NaN      NaN              NaN  COVID19  PFIZER\BIONTECH
#
#   vax_lot vax_dose_series vax_route  vax_site  \
# 0     NaN               1       NaN       NaN
# 1     NaN               1       NaN       NaN
# 2  EJ1685               1        OT        LA
# 3     NaN               1       NaN       NaN
# 4     NaN               1       NaN        RA
#
#                               vax_name
# 0  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4  COVID19 (COVID19 (PFIZER-BIONTECH))
#
# [5 rows x 49 columns]

# %%
#Keep only the age, gender, died, and vax name columns for unsupervised model then remove null values and convert to numeric. 
vaers_df_UML = vaers_df[['vaers_id','age_yrs', 'sex', 'died', 'vax_name' ]]
vaers_df_UML.head(10)
# Out:
#    vaers_id  age_yrs sex died                             vax_name
# 0   1000000      NaN   M  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1   1000001      NaN   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2   1000003     29.0   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3   1000006      NaN   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4   1000007     53.0   M  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 5   1000012      NaN   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 6   1000013      NaN   M  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 7   1000015      NaN   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8   1000021     62.0   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 9   1000031      NaN   F  NaN  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
# Check vaers_df column types
vaers_df_UML.dtypes
# Out:
# vaers_id      int64
# age_yrs     float64
# sex          object
# died         object
# vax_name     object
# dtype: object

# %%
vaers_df_UML['died'].fillna(value='N', inplace=True)
vaers_df_UML.died
# Out:
# C:\Users\Kanav\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
#         ..
# 40242    N
# 40243    N
# 40244    N
# 40245    N
# 40246    N
# Name: died, Length: 40209, dtype: object

# %%
vaers_UML = vaers_df_UML.dropna()
vaers_UML.head(10)
# Out:
#     vaers_id  age_yrs sex died                             vax_name
# 2    1000003     29.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4    1000007     53.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8    1000021     62.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10   1000036     38.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13   1000046     86.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14   1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15   1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16   1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19   1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20   1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
vaers_UML.sex.value_counts()
# Out:
# F    26778
# M     9902
# U      176
# Name: sex, dtype: int64

# %%
vaers_UML.died.value_counts()
# Out:
# N    34430
# Y     2426
# Name: died, dtype: int64

# %%
pd.options.display.max_rows = None
vaers_UML.vax_name.value_counts()
# Out:
# COVID19 (COVID19 (MODERNA))                              18546
# COVID19 (COVID19 (PFIZER-BIONTECH))                      17460
# COVID19 (COVID19 (JANSSEN))                                401
# VACCINE NOT SPECIFIED (NO BRAND NAME)                       95
# ZOSTER (SHINGRIX)                                           62
# COVID19 (COVID19 (UNKNOWN))                                 30
# INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)                 25
# PNEUMO (PNEUMOVAX)                                          23
# INFLUENZA (SEASONAL) (NO BRAND NAME)                        21
# VACCINE NOT SPECIFIED (OTHER)                               15
# INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE QUADRIVALENT)       15
# MEASLES + MUMPS + RUBELLA (MMR II)                          13
# ZOSTER LIVE (ZOSTAVAX)                                      12
# INFLUENZA (SEASONAL) (FLUBLOK QUADRIVALENT)                 11
# VARICELLA (VARIVAX)                                          8
# INFLUENZA (SEASONAL) (FLULAVAL QUADRIVALENT)                 8
# INFLUENZA (SEASONAL) (FLUAD QUADRIVALENT)                    8
# HPV (GARDASIL 9)                                             7
# HPV (NO BRAND NAME)                                          6
# TDAP (ADACEL)                                                6
# INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)                  6
# INFLUENZA (SEASONAL) (AFLURIA QUADRIVALENT)                  5
# INFLUENZA (SEASONAL) (FLUCELVAX QUADRIVALENT)                5
# PNEUMO (PREVNAR13)                                           5
# MENINGOCOCCAL CONJUGATE (MENACTRA)                           5
# DTAP + HEPB + IPV (PEDIARIX)                                 4
# MENINGOCOCCAL B (TRUMENBA)                                   4
# HEP A (HAVRIX)                                               4
# HEP A (VAQTA)                                                4
# HEP B (NO BRAND NAME)                                        4
# INFLUENZA (SEASONAL) (FLUZONE)                               4
# HEP B (ENGERIX-B)                                            3
# INFLUENZA (SEASONAL) (FLUAD)                                 3
# HIB (ACTHIB)                                                 3
# ROTAVIRUS (ROTARIX)                                          3
# DT ADSORBED (NO BRAND NAME)                                  3
# POLIO VIRUS, ORAL (NO BRAND NAME)                            2
# TETANUS TOXOID (NO BRAND NAME)                               2
# DTAP + IPV + HIB (PENTACEL)                                  2
# INFLUENZA (SEASONAL) (FLUMIST QUADRIVALENT)                  2
# YELLOW FEVER (YF-VAX)                                        2
# CHOLERA (NO BRAND NAME)                                      1
# MENINGOCOCCAL CONJUGATE (MENVEO)                             1
# ROTAVIRUS (ROTATEQ)                                          1
# DTAP (DAPTACEL)                                              1
# HEP B (RECOMBIVAX HB)                                        1
# PNEUMO (PREVNAR)                                             1
# HIB (PEDVAXHIB)                                              1
# DTAP (INFANRIX)                                              1
# HEP B (HEPLISAV-B)                                           1
# Name: vax_name, dtype: int64

# %%
#Export CSV for dashboard purposes
vaers_UML.to_csv('VAERS_UML_cleaned.csv')

# %%
#Remove all values in vax_name that do not include 'COVID19' using REGEX, in order to select only the top three unique values in 
#vax_name. Therefore the only three vaccines will be three covid19 vaccines; moderna, pfizer-biontech, and janssen. 
regex = r' \b(\w*COVID19\w*)\b'

# %%
#Use REGEX to filter for only COVID19 
vax_names = vaers_UML['vax_name']
vax_names.str.contains(regex, flags=re.IGNORECASE).sum()

# %%
#Convert sex column from object to boolean numerical values for unsupervised model
def change_sex(sex):
    if sex == "M":
        return 1
    if sex == "F":
        return 2
    else: 
        return 3
    
vaers_UML ["sex"] = vaers_UML["sex"].apply(change_sex)
vaers_UML.head(10)
# Out:
# C:\Users\Kanav\anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#     vaers_id  age_yrs  sex died                             vax_name
# 2    1000003     29.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4    1000007     53.0    1    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8    1000021     62.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10   1000036     38.0    1    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13   1000046     86.0    1    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14   1000051     70.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15   1000051     70.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16   1000051     70.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19   1000074     80.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20   1000074     80.0    2    N  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
#Convert died column from object to boolean numerical values for unsupervised model
def change_died(died):
    if died == "N":
        return 1
    else: 
        return 2
    
vaers_UML ["died"] = vaers_UML["died"].apply(change_died)
vaers_UML.head(10)
# Out:
# C:\Users\Kanav\anaconda3\envs\PythonData2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     vaers_id  age_yrs  sex  died                             vax_name
# 2    1000003     29.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4    1000007     53.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8    1000021     62.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10   1000036     38.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13   1000046     86.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19   1000074     80.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20   1000074     80.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
#Convert vax_name column from object to numerical values for unsupervised model, representing each vaccine (Moderna, Pfizer, Janssen)

# %%
vaers_UML.sex.value_counts()
# Out:
# 2    26778
# 1     9902
# 3      176
# Name: sex, dtype: int64

# %%
vaers_UML.died.value_counts()
# Out:
# 1    34430
# 2     2426
# Name: died, dtype: int64

# %%
#Now that columns are numerical, change column types from "object" for unsuprvised model purposes

# %%
# Check vaers_df column types
vaers_df_UML.dtypes
# Out:
# vaers_id      int64
# age_yrs     float64
# sex          object
# died         object
# vax_name     object
# dtype: object

# %%
vaers_UML.head(10)
# Out:
#     vaers_id  age_yrs  sex  died                             vax_name
# 2    1000003     29.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4    1000007     53.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8    1000021     62.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10   1000036     38.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13   1000046     86.0    1     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16   1000051     70.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19   1000074     80.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20   1000074     80.0    2     1  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
#Convert vax_name column from object to numerical values for unsupervised model, representing each vaccine (Moderna, Pfizer, Janssen)

# %%
# Conduct unsupervised machine learning model
