# %% [markdown]
# # CREATE CLEANED CSV CONTAINING FEATURES (INDEX, VAERS_ID, SEX, AGE_YRS, VAX_NAME)

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.base import TransformerMixin
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import tensorflow as tf
import re
from sqlalchemy import create_engine  
from sqlalchemy import Column, String  
from sqlalchemy.ext.declarative import declarative_base  
from sqlalchemy.orm import sessionmaker
import pandas.io.sql as sqlio
import psycopg2

# %%
# Use psycopg2 to import cleaned table from pgadmin
conn = psycopg2.connect("dbname=VAERS user=postgres password=")
sql = "select * from vaers_3;"
vaers_df = sqlio.read_sql_query(sql, conn)
conn = None

# %%
# Print DF
print(vaers_df.shape)
vaers_df.head(5)
# Out:
# (40247, 49)
#   vaers_id    recvdate state_  age_yrs  cage_yr sex  \
# 0  1000000  02/04/2021     CA      NaN      NaN   M
# 1  1000001  02/04/2021     WI      NaN      NaN   F
# 2  1000003  02/04/2021     PA     29.0      NaN   F
# 3  1000006  02/04/2021   None      NaN      NaN   F
# 4  1000007  02/04/2021     WI     53.0      NaN   M
#
#                                         symptom_text  died datedied l_threat  \
# 0  tested positive; tested positive; This is a sp...  None     None     None
# 1  covid symptoms the 28th and tested positive; c...  None     None     None
# 2  rash and hives all over body; rash and hives a...  None     None     None
# 3  tested positive for covid; tested positive for...  None     None     None
# 4  blood sugar has been out of control ranging fr...  None     None     None
#
#    ... symptomversion4 symptom5  symptomversion5 vax_type         vax_manu  \
# 0  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 1  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 2  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 3  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 4  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
#
#   vax_lot vax_dose_series vax_route  vax_site  \
# 0    None               1      None      None
# 1    None               1      None      None
# 2  EJ1685               1        OT        LA
# 3    None               1      None      None
# 4    None               1      None        RA
#
#                               vax_name
# 0  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4  COVID19 (COVID19 (PFIZER-BIONTECH))
#
# [5 rows x 49 columns]

# %%
# Drop duplicates in the dataframe
vaers_df.drop_duplicates(inplace=True)
print(vaers_df.shape)
vaers_df.head(5)
# Out:
# (40209, 49)
#   vaers_id    recvdate state_  age_yrs  cage_yr sex  \
# 0  1000000  02/04/2021     CA      NaN      NaN   M
# 1  1000001  02/04/2021     WI      NaN      NaN   F
# 2  1000003  02/04/2021     PA     29.0      NaN   F
# 3  1000006  02/04/2021   None      NaN      NaN   F
# 4  1000007  02/04/2021     WI     53.0      NaN   M
#
#                                         symptom_text  died datedied l_threat  \
# 0  tested positive; tested positive; This is a sp...  None     None     None
# 1  covid symptoms the 28th and tested positive; c...  None     None     None
# 2  rash and hives all over body; rash and hives a...  None     None     None
# 3  tested positive for covid; tested positive for...  None     None     None
# 4  blood sugar has been out of control ranging fr...  None     None     None
#
#    ... symptomversion4 symptom5  symptomversion5 vax_type         vax_manu  \
# 0  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 1  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 2  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 3  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
# 4  ...             NaN     None              NaN  COVID19  PFIZER\BIONTECH
#
#   vax_lot vax_dose_series vax_route  vax_site  \
# 0    None               1      None      None
# 1    None               1      None      None
# 2  EJ1685               1        OT        LA
# 3    None               1      None      None
# 4    None               1      None        RA
#
#                               vax_name
# 0  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4  COVID19 (COVID19 (PFIZER-BIONTECH))
#
# [5 rows x 49 columns]

# %%
#Keep only the age, gender, died, and vax name columns for unsupervised model
vaers_df_UML = vaers_df[['vaers_id','age_yrs', 'sex', 'died', 'vax_name' ]]
vaers_df_UML.head(10)
# Out:
#   vaers_id  age_yrs sex  died                             vax_name
# 0  1000000      NaN   M  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1  1000001      NaN   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2  1000003     29.0   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3  1000006      NaN   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4  1000007     53.0   M  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 5  1000012      NaN   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 6  1000013      NaN   M  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 7  1000015      NaN   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8  1000021     62.0   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))
# 9  1000031      NaN   F  None  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
# Check vaers_df column types
vaers_df_UML.dtypes
# Out:
# vaers_id     object
# age_yrs     float64
# sex          object
# died         object
# vax_name     object
# dtype: object

# %%
# Convert missing data in 'died' column to indicate that death has not occured ("Y"/"N")
vaers_df_UML['died'].fillna(value='N', inplace=True)
vaers_df_UML.died
# Out:
# C:\Users\Kanav\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
#         ..
# 40242    N
# 40243    N
# 40244    N
# 40245    N
# 40246    N
# Name: died, Length: 40209, dtype: object

# %%
# Create new DF that does not contain null values
vaers_UML = vaers_df_UML.dropna()
vaers_UML.head(10)
# Out:
#    vaers_id  age_yrs sex died                             vax_name
# 2   1000003     29.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4   1000007     53.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8   1000021     62.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10  1000036     38.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13  1000046     86.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
# Analyze 'sex' column
vaers_UML.sex.value_counts()
# Out:
# F    26778
# M     9902
# U      176
# Name: sex, dtype: int64

# %%
# Analyze 'died' column
vaers_UML.died.value_counts()
# Out:
# N    34430
# Y     2426
# Name: died, dtype: int64

# %%
# Analyze 'vax_name' column
pd.options.display.max_rows = None
vaers_UML.vax_name.value_counts()
# Out:
# COVID19 (COVID19 (MODERNA))                              18546
# COVID19 (COVID19 (PFIZER-BIONTECH))                      17460
# COVID19 (COVID19 (JANSSEN))                                401
# VACCINE NOT SPECIFIED (NO BRAND NAME)                       95
# ZOSTER (SHINGRIX)                                           62
# COVID19 (COVID19 (UNKNOWN))                                 30
# INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)                 25
# PNEUMO (PNEUMOVAX)                                          23
# INFLUENZA (SEASONAL) (NO BRAND NAME)                        21
# INFLUENZA (SEASONAL) (FLUZONE HIGH-DOSE QUADRIVALENT)       15
# VACCINE NOT SPECIFIED (OTHER)                               15
# MEASLES + MUMPS + RUBELLA (MMR II)                          13
# ZOSTER LIVE (ZOSTAVAX)                                      12
# INFLUENZA (SEASONAL) (FLUBLOK QUADRIVALENT)                 11
# INFLUENZA (SEASONAL) (FLUAD QUADRIVALENT)                    8
# VARICELLA (VARIVAX)                                          8
# INFLUENZA (SEASONAL) (FLULAVAL QUADRIVALENT)                 8
# HPV (GARDASIL 9)                                             7
# INFLUENZA (SEASONAL) (FLUARIX QUADRIVALENT)                  6
# TDAP (ADACEL)                                                6
# HPV (NO BRAND NAME)                                          6
# MENINGOCOCCAL CONJUGATE (MENACTRA)                           5
# INFLUENZA (SEASONAL) (FLUCELVAX QUADRIVALENT)                5
# PNEUMO (PREVNAR13)                                           5
# INFLUENZA (SEASONAL) (AFLURIA QUADRIVALENT)                  5
# HEP A (HAVRIX)                                               4
# DTAP + HEPB + IPV (PEDIARIX)                                 4
# HEP A (VAQTA)                                                4
# MENINGOCOCCAL B (TRUMENBA)                                   4
# INFLUENZA (SEASONAL) (FLUZONE)                               4
# HEP B (NO BRAND NAME)                                        4
# INFLUENZA (SEASONAL) (FLUAD)                                 3
# HIB (ACTHIB)                                                 3
# DT ADSORBED (NO BRAND NAME)                                  3
# ROTAVIRUS (ROTARIX)                                          3
# HEP B (ENGERIX-B)                                            3
# INFLUENZA (SEASONAL) (FLUMIST QUADRIVALENT)                  2
# DTAP + IPV + HIB (PENTACEL)                                  2
# YELLOW FEVER (YF-VAX)                                        2
# POLIO VIRUS, ORAL (NO BRAND NAME)                            2
# TETANUS TOXOID (NO BRAND NAME)                               2
# HEP B (HEPLISAV-B)                                           1
# HEP B (RECOMBIVAX HB)                                        1
# MENINGOCOCCAL CONJUGATE (MENVEO)                             1
# PNEUMO (PREVNAR)                                             1
# HIB (PEDVAXHIB)                                              1
# ROTAVIRUS (ROTATEQ)                                          1
# DTAP (INFANRIX)                                              1
# CHOLERA (NO BRAND NAME)                                      1
# DTAP (DAPTACEL)                                              1
# Name: vax_name, dtype: int64

# %%
# Filter the vax_name column for values that contain "COVID19"
vaers_UML = vaers_UML[vaers_UML['vax_name'].str.contains("COVID19")]
vaers_UML.head(10)
# Out:
#    vaers_id  age_yrs sex died                             vax_name
# 2   1000003     29.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4   1000007     53.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8   1000021     62.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10  1000036     38.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13  1000046     86.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
#Check if only desired values remain
pd.options.display.max_rows = None
vaers_UML.vax_name.value_counts()
# Out:
# COVID19 (COVID19 (MODERNA))            18546
# COVID19 (COVID19 (PFIZER-BIONTECH))    17460
# COVID19 (COVID19 (JANSSEN))              401
# COVID19 (COVID19 (UNKNOWN))               30
# Name: vax_name, dtype: int64

# %%
# Analyze values
vaers_UML.sex.value_counts()
# Out:
# F    26510
# M     9760
# U      167
# Name: sex, dtype: int64

# %%
# Analyze values
vaers_UML.died.value_counts()
# Out:
# N    34084
# Y     2353
# Name: died, dtype: int64

# %%
#Tidy vax_name column by removing "COVID19" entered twice each row, and unnecessary parenthesis
vaccine_name = vaers_UML['vax_name'].astype(str)
vaccine_name.head()
# Out:
# 2     COVID19 (COVID19 (PFIZER-BIONTECH))
# 4     COVID19 (COVID19 (PFIZER-BIONTECH))
# 8     COVID19 (COVID19 (PFIZER-BIONTECH))
# 10    COVID19 (COVID19 (PFIZER-BIONTECH))
# 13    COVID19 (COVID19 (PFIZER-BIONTECH))
# Name: vax_name, dtype: object

# %%
#Split text
vaccine_name = vaccine_name.str.split("(", n=2, expand = True)
vaccine_name.head()
# Out:
#            0         1                  2
# 2   COVID19   COVID19   PFIZER-BIONTECH))
# 4   COVID19   COVID19   PFIZER-BIONTECH))
# 8   COVID19   COVID19   PFIZER-BIONTECH))
# 10  COVID19   COVID19   PFIZER-BIONTECH))
# 13  COVID19   COVID19   PFIZER-BIONTECH))

# %%
# Set equal to vaccine name
vaccine_name = vaccine_name[2]

# %%
# Remove parenthesis at the end of each row
vaccine_name = vaccine_name.str.replace(r"\).*\)","")

# %%
# Check results
vaccine_name.head()
# Out:
# 2     PFIZER-BIONTECH
# 4     PFIZER-BIONTECH
# 8     PFIZER-BIONTECH
# 10    PFIZER-BIONTECH
# 13    PFIZER-BIONTECH
# Name: 2, dtype: object

# %%
# Check results
vaers_UML.head(15)
# Out:
#    vaers_id  age_yrs sex died                             vax_name
# 2   1000003     29.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4   1000007     53.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 8   1000021     62.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 10  1000036     38.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 13  1000046     86.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 14  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 15  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 16  1000051     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 19  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 20  1000074     80.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 22  1000082     70.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 24  1000103     54.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 25  1000103     54.0   M    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 29  1000122     36.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))
# 30  1000124     73.0   F    N  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
# set vax_name columns to new variable
vaers_UML['vax_name'] = vaccine_name

# %%
# Check results
vaers_UML.head(50)
# Out:
#    vaers_id  age_yrs sex died         vax_name
# 2   1000003     29.0   F    N  PFIZER-BIONTECH
# 4   1000007     53.0   M    N  PFIZER-BIONTECH
# 8   1000021     62.0   F    N  PFIZER-BIONTECH
# 10  1000036     38.0   M    N  PFIZER-BIONTECH
# 13  1000046     86.0   M    N  PFIZER-BIONTECH
# 14  1000051     70.0   F    N  PFIZER-BIONTECH
# 15  1000051     70.0   F    N  PFIZER-BIONTECH
# 16  1000051     70.0   F    N  PFIZER-BIONTECH
# 19  1000074     80.0   F    N  PFIZER-BIONTECH
# 20  1000074     80.0   F    N  PFIZER-BIONTECH
# 22  1000082     70.0   F    N  PFIZER-BIONTECH
# 24  1000103     54.0   M    N  PFIZER-BIONTECH
# 25  1000103     54.0   M    N  PFIZER-BIONTECH
# 29  1000122     36.0   F    N  PFIZER-BIONTECH
# 30  1000124     73.0   F    N  PFIZER-BIONTECH
# 31  1000124     73.0   F    N  PFIZER-BIONTECH
# 32  1000124     73.0   F    N  PFIZER-BIONTECH
# 34  1000134     19.0   F    N  PFIZER-BIONTECH
# 35  1000134     19.0   F    N  PFIZER-BIONTECH
# 37  1000147     72.0   F    N  PFIZER-BIONTECH
# 38  1000149     54.0   F    N  PFIZER-BIONTECH
# 40  1000159     65.0   M    N  PFIZER-BIONTECH
# 42  1000165     39.0   M    N          MODERNA
# 44  1000169     50.0   F    N          MODERNA
# 45  1000170     73.0   M    N  PFIZER-BIONTECH
# 46  1000172     55.0   F    N          MODERNA
# 48  1000175     38.0   F    N          MODERNA
# 51  1000191     47.0   F    N  PFIZER-BIONTECH
# 54  1000199     56.0   M    N  PFIZER-BIONTECH
# 56  1000206     49.0   F    N  PFIZER-BIONTECH
# 57  1000206     49.0   F    N  PFIZER-BIONTECH
# 58  1000207     32.0   F    N  PFIZER-BIONTECH
# 59  1000209     49.0   F    N  PFIZER-BIONTECH
# 60  1000210     34.0   F    N  PFIZER-BIONTECH
# 61  1000212     38.0   M    N  PFIZER-BIONTECH
# 62  1000212     38.0   M    N  PFIZER-BIONTECH
# 63  1000213     52.0   F    N  PFIZER-BIONTECH
# 64  1000213     52.0   F    N  PFIZER-BIONTECH
# 66  1000215     45.0   F    N  PFIZER-BIONTECH
# 67  1000216     81.0   M    N  PFIZER-BIONTECH
# 68  1000216     81.0   M    N  PFIZER-BIONTECH
# 69  1000217     94.0   F    N  PFIZER-BIONTECH
# 70  1000217     94.0   F    N  PFIZER-BIONTECH
# 71  1000218     87.0   F    N  PFIZER-BIONTECH
# 72  1000218     87.0   F    N  PFIZER-BIONTECH
# 73  1000219     67.0   F    N  PFIZER-BIONTECH
# 74  1000219     67.0   F    N  PFIZER-BIONTECH
# 75  1000226     86.0   F    Y  PFIZER-BIONTECH
# 76  1000227     67.0   M    N  PFIZER-BIONTECH
# 77  1000228     40.0   M    Y  PFIZER-BIONTECH

# %%
#Export CSV for dashboard use, proceed to convert text strings to numerical values
vaers_UML.to_csv('VAERS_UML_cleaned.csv')

# %% [markdown]
# # CREATE CLEANED DATAFRAME FOR UNSUPERVISED MACHINE-LEARNING (ONLY NUMERICAL DATA)

# %%
#Convert sex column from object to boolean numerical values for unsupervised model
def change_sex(sex):
    if sex == "M":
        return 1
    if sex == "F":
        return 2
    else: 
        return 3
    
vaers_UML ["sex"] = vaers_UML["sex"].apply(change_sex)
vaers_UML.head(10)
# Out:
#    vaers_id  age_yrs  sex died         vax_name
# 2   1000003     29.0    2    N  PFIZER-BIONTECH
# 4   1000007     53.0    1    N  PFIZER-BIONTECH
# 8   1000021     62.0    2    N  PFIZER-BIONTECH
# 10  1000036     38.0    1    N  PFIZER-BIONTECH
# 13  1000046     86.0    1    N  PFIZER-BIONTECH
# 14  1000051     70.0    2    N  PFIZER-BIONTECH
# 15  1000051     70.0    2    N  PFIZER-BIONTECH
# 16  1000051     70.0    2    N  PFIZER-BIONTECH
# 19  1000074     80.0    2    N  PFIZER-BIONTECH
# 20  1000074     80.0    2    N  PFIZER-BIONTECH

# %%
#Convert died column from object to boolean numerical values for unsupervised model
def change_died(died):
    if died == "N":
        return 1
    else: 
        return 2
    
vaers_UML ["died"] = vaers_UML["died"].apply(change_died)
vaers_UML.head(15)
# Out:
#    vaers_id  age_yrs  sex  died         vax_name
# 2   1000003     29.0    2     1  PFIZER-BIONTECH
# 4   1000007     53.0    1     1  PFIZER-BIONTECH
# 8   1000021     62.0    2     1  PFIZER-BIONTECH
# 10  1000036     38.0    1     1  PFIZER-BIONTECH
# 13  1000046     86.0    1     1  PFIZER-BIONTECH
# 14  1000051     70.0    2     1  PFIZER-BIONTECH
# 15  1000051     70.0    2     1  PFIZER-BIONTECH
# 16  1000051     70.0    2     1  PFIZER-BIONTECH
# 19  1000074     80.0    2     1  PFIZER-BIONTECH
# 20  1000074     80.0    2     1  PFIZER-BIONTECH
# 22  1000082     70.0    2     1  PFIZER-BIONTECH
# 24  1000103     54.0    1     1  PFIZER-BIONTECH
# 25  1000103     54.0    1     1  PFIZER-BIONTECH
# 29  1000122     36.0    2     1  PFIZER-BIONTECH
# 30  1000124     73.0    2     1  PFIZER-BIONTECH

# %%
vaers_UML["vax_name"]
# Out:
# 2        PFIZER-BIONTECH
# 4        PFIZER-BIONTECH
# 8        PFIZER-BIONTECH
# 10       PFIZER-BIONTECH
# 13       PFIZER-BIONTECH
# 14       PFIZER-BIONTECH
# 15       PFIZER-BIONTECH
# 16       PFIZER-BIONTECH
# 19       PFIZER-BIONTECH
# 20       PFIZER-BIONTECH
# 22       PFIZER-BIONTECH
# 24       PFIZER-BIONTECH
# 25       PFIZER-BIONTECH
# 29       PFIZER-BIONTECH
# 30       PFIZER-BIONTECH
# 31       PFIZER-BIONTECH
# 32       PFIZER-BIONTECH
# 34       PFIZER-BIONTECH
# 35       PFIZER-BIONTECH
# 37       PFIZER-BIONTECH
# 38       PFIZER-BIONTECH
# 40       PFIZER-BIONTECH
# 42               MODERNA
# 44               MODERNA
# 45       PFIZER-BIONTECH
# 46               MODERNA
# 48               MODERNA
# 51       PFIZER-BIONTECH
# 54       PFIZER-BIONTECH
# 56       PFIZER-BIONTECH
# 57       PFIZER-BIONTECH
# 58       PFIZER-BIONTECH
# 59       PFIZER-BIONTECH
# 60       PFIZER-BIONTECH
# 61       PFIZER-BIONTECH
# 62       PFIZER-BIONTECH
# 63       PFIZER-BIONTECH
# 64       PFIZER-BIONTECH
# 66       PFIZER-BIONTECH
# 67       PFIZER-BIONTECH
# 68       PFIZER-BIONTECH
# 69       PFIZER-BIONTECH
# 70       PFIZER-BIONTECH
# 71       PFIZER-BIONTECH
# 72       PFIZER-BIONTECH
# 73       PFIZER-BIONTECH
# 74       PFIZER-BIONTECH
# 75       PFIZER-BIONTECH
# 76       PFIZER-BIONTECH
# 77       PFIZER-BIONTECH
# 78       PFIZER-BIONTECH
# 79       PFIZER-BIONTECH
# 81       PFIZER-BIONTECH
# 82               MODERNA
# 83               MODERNA
# 84       PFIZER-BIONTECH
# 85               MODERNA
# 86       PFIZER-BIONTECH
# 87               MODERNA
# 88       PFIZER-BIONTECH
# 89               MODERNA
# 90               MODERNA
# 91       PFIZER-BIONTECH
# 92               MODERNA
# 93               MODERNA
# 94       PFIZER-BIONTECH
# 95       PFIZER-BIONTECH
# 96       PFIZER-BIONTECH
# 97       PFIZER-BIONTECH
# 98       PFIZER-BIONTECH
# 99               MODERNA
# 100              MODERNA
# 101              MODERNA
# 102              MODERNA
# 103              MODERNA
# 104      PFIZER-BIONTECH
# 105              MODERNA
# 111      PFIZER-BIONTECH
# 112      PFIZER-BIONTECH
# 114      PFIZER-BIONTECH
# 115      PFIZER-BIONTECH
# 116      PFIZER-BIONTECH
# 117      PFIZER-BIONTECH
# 120      PFIZER-BIONTECH
# 123      PFIZER-BIONTECH
# 125      PFIZER-BIONTECH
# 127      PFIZER-BIONTECH
# 128      PFIZER-BIONTECH
# 130      PFIZER-BIONTECH
# 132      PFIZER-BIONTECH
# 136      PFIZER-BIONTECH
# 137      PFIZER-BIONTECH
# 138      PFIZER-BIONTECH
# 139      PFIZER-BIONTECH
# 140      PFIZER-BIONTECH
# 141      PFIZER-BIONTECH
# 142      PFIZER-BIONTECH
# 143      PFIZER-BIONTECH
# 144      PFIZER-BIONTECH
# 145      PFIZER-BIONTECH
# 146      PFIZER-BIONTECH
# 147      PFIZER-BIONTECH
# 148      PFIZER-BIONTECH
# 149      PFIZER-BIONTECH
# 150      PFIZER-BIONTECH
# 151      PFIZER-BIONTECH
# 152      PFIZER-BIONTECH
# 153      PFIZER-BIONTECH
# 154      PFIZER-BIONTECH
# 155      PFIZER-BIONTECH
# 156      PFIZER-BIONTECH
# 157      PFIZER-BIONTECH
# 158      PFIZER-BIONTECH
# 159      PFIZER-BIONTECH
# 160      PFIZER-BIONTECH
# 163      PFIZER-BIONTECH
# 165      PFIZER-BIONTECH
# 166      PFIZER-BIONTECH
# 167      PFIZER-BIONTECH
# 169              MODERNA
# 170              MODERNA
# 171              MODERNA
# 172              MODERNA
# 173      PFIZER-BIONTECH
# 174              MODERNA
# 175      PFIZER-BIONTECH
# 176              MODERNA
# 177              MODERNA
# 178              MODERNA
# 179              MODERNA
# 180      PFIZER-BIONTECH
# 181      PFIZER-BIONTECH
# 182              MODERNA
# 183              MODERNA
# 184              MODERNA
# 185              MODERNA
# 186      PFIZER-BIONTECH
# 187              MODERNA
# 188              MODERNA
# 189              MODERNA
# 190              MODERNA
# 191              MODERNA
# 192      PFIZER-BIONTECH
# 193      PFIZER-BIONTECH
# 194      PFIZER-BIONTECH
# 195      PFIZER-BIONTECH
# 196      PFIZER-BIONTECH
# 197              MODERNA
# 198      PFIZER-BIONTECH
# 199      PFIZER-BIONTECH
# 200      PFIZER-BIONTECH
# 201              MODERNA
# 202              MODERNA
# 203      PFIZER-BIONTECH
# 204      PFIZER-BIONTECH
# 205              MODERNA
# 206      PFIZER-BIONTECH
# 207      PFIZER-BIONTECH
# 208              MODERNA
# 209              MODERNA
# 210              MODERNA
# 211      PFIZER-BIONTECH
# 212              MODERNA
# 213              MODERNA
# 214              MODERNA
# 215              MODERNA
# 216              MODERNA
# 217              MODERNA
# 218              MODERNA
# 219              MODERNA
# 220              MODERNA
# 221              MODERNA
# 222              MODERNA
# 223              MODERNA
# 224              MODERNA
# 225              MODERNA
# 226      PFIZER-BIONTECH
# 227              MODERNA
# 228              MODERNA
# 229      PFIZER-BIONTECH
# 230      PFIZER-BIONTECH
# 231      PFIZER-BIONTECH
# 232              MODERNA
# 233      PFIZER-BIONTECH
# 234              MODERNA
# 235      PFIZER-BIONTECH
# 236              MODERNA
# 237              MODERNA
# 238      PFIZER-BIONTECH
# 239      PFIZER-BIONTECH
# 241              MODERNA
# 242      PFIZER-BIONTECH
# 243      PFIZER-BIONTECH
# 244              MODERNA
# 245              MODERNA
# 246      PFIZER-BIONTECH
# 247              MODERNA
# 248              MODERNA
# 249      PFIZER-BIONTECH
# 250      PFIZER-BIONTECH
# 251      PFIZER-BIONTECH
# 252      PFIZER-BIONTECH
# 253      PFIZER-BIONTECH
# 254              MODERNA
# 255              MODERNA
# 256              MODERNA
# 257              MODERNA
# 258              MODERNA
# 259      PFIZER-BIONTECH
# 261      PFIZER-BIONTECH
# 262      PFIZER-BIONTECH
# 263      PFIZER-BIONTECH
# 264      PFIZER-BIONTECH
# 265              MODERNA
# 266              MODERNA
# 267              MODERNA
# 268              MODERNA
# 269              MODERNA
# 270              MODERNA
# 271              MODERNA
# 272              MODERNA
# 273      PFIZER-BIONTECH
# 274              MODERNA
# 275              MODERNA
# 276      PFIZER-BIONTECH
# 280              MODERNA
# 281              MODERNA
# 285              MODERNA
# 287              MODERNA
# 288              MODERNA
# 290              MODERNA
# 295      PFIZER-BIONTECH
# 296      PFIZER-BIONTECH
# 297      PFIZER-BIONTECH
# 298      PFIZER-BIONTECH
# 299      PFIZER-BIONTECH
# 300      PFIZER-BIONTECH
# 301      PFIZER-BIONTECH
# 303              UNKNOWN
# 304      PFIZER-BIONTECH
# 305      PFIZER-BIONTECH
# 306      PFIZER-BIONTECH
# 307      PFIZER-BIONTECH
# 309      PFIZER-BIONTECH
# 310              MODERNA
# 311              MODERNA
# 312              MODERNA
# 313              MODERNA
# 314              MODERNA
# 315              MODERNA
# 316              MODERNA
# 320              MODERNA
# 321              MODERNA
# 325              MODERNA
# 326              MODERNA
# 327              MODERNA
# 328              MODERNA
# 329              MODERNA
# 330              MODERNA
# 334              MODERNA
# 335              MODERNA
# 336      PFIZER-BIONTECH
# 337      PFIZER-BIONTECH
# 339      PFIZER-BIONTECH
# 341      PFIZER-BIONTECH
# 342              MODERNA
# 343              MODERNA
# 344              MODERNA
# 345              MODERNA
# 346              MODERNA
# 347              MODERNA
# 348              MODERNA
# 349              MODERNA
# 350      PFIZER-BIONTECH
# 351              MODERNA
# 352              MODERNA
# 353              MODERNA
# 354      PFIZER-BIONTECH
# 355      PFIZER-BIONTECH
# 356      PFIZER-BIONTECH
# 357      PFIZER-BIONTECH
# 358      PFIZER-BIONTECH
# 359      PFIZER-BIONTECH
# 360      PFIZER-BIONTECH
# 361      PFIZER-BIONTECH
# 362      PFIZER-BIONTECH
# 363      PFIZER-BIONTECH
# 364      PFIZER-BIONTECH
# 365      PFIZER-BIONTECH
# 366      PFIZER-BIONTECH
# 367              MODERNA
# 368              MODERNA
# 369      PFIZER-BIONTECH
# 370              MODERNA
# 371      PFIZER-BIONTECH
# 372              MODERNA
# 373              MODERNA
# 374      PFIZER-BIONTECH
# 375      PFIZER-BIONTECH
# 376      PFIZER-BIONTECH
# 377      PFIZER-BIONTECH
# 378      PFIZER-BIONTECH
# 379      PFIZER-BIONTECH
# 380      PFIZER-BIONTECH
# 381      PFIZER-BIONTECH
# 382      PFIZER-BIONTECH
# 383      PFIZER-BIONTECH
# 384      PFIZER-BIONTECH
# 385      PFIZER-BIONTECH
# 386      PFIZER-BIONTECH
# 387              MODERNA
# 388              MODERNA
# 389              MODERNA
# 390      PFIZER-BIONTECH
# 391              MODERNA
# 392              MODERNA
# 393      PFIZER-BIONTECH
# 394      PFIZER-BIONTECH
# 395      PFIZER-BIONTECH
# 396      PFIZER-BIONTECH
# 397              MODERNA
# 398              MODERNA
# 399      PFIZER-BIONTECH
# 400      PFIZER-BIONTECH
# 401              MODERNA
# 402              MODERNA
# 403      PFIZER-BIONTECH
# 404              MODERNA
# 405              MODERNA
# 406      PFIZER-BIONTECH
# 407      PFIZER-BIONTECH
# 408      PFIZER-BIONTECH
# 409      PFIZER-BIONTECH
# 410              MODERNA
# 411              MODERNA
# 412              MODERNA
# 413              MODERNA
# 415      PFIZER-BIONTECH
# 416      PFIZER-BIONTECH
# 417      PFIZER-BIONTECH
# 418      PFIZER-BIONTECH
# 419              MODERNA
# 420              MODERNA
# 421      PFIZER-BIONTECH
# 422              MODERNA
# 423              MODERNA
# 424              MODERNA
# 425              MODERNA
# 426      PFIZER-BIONTECH
# 427      PFIZER-BIONTECH
# 428      PFIZER-BIONTECH
# 429      PFIZER-BIONTECH
# 430      PFIZER-BIONTECH
# 431      PFIZER-BIONTECH
# 432      PFIZER-BIONTECH
# 433      PFIZER-BIONTECH
# 434      PFIZER-BIONTECH
# 435              MODERNA
# 436      PFIZER-BIONTECH
# 437              MODERNA
# 438              MODERNA
# 439      PFIZER-BIONTECH
# 440      PFIZER-BIONTECH
# 441      PFIZER-BIONTECH
# 442              MODERNA
# 443      PFIZER-BIONTECH
# 444              MODERNA
# 445              MODERNA
# 446              MODERNA
# 447              MODERNA
# 448              MODERNA
# 449              MODERNA
# 450              MODERNA
# 451              MODERNA
# 452      PFIZER-BIONTECH
# 453      PFIZER-BIONTECH
# 454              MODERNA
# 455              MODERNA
# 456      PFIZER-BIONTECH
# 457      PFIZER-BIONTECH
# 458      PFIZER-BIONTECH
# 459      PFIZER-BIONTECH
# 460      PFIZER-BIONTECH
# 461              MODERNA
# 462              MODERNA
# 463      PFIZER-BIONTECH
# 464              MODERNA
# 465      PFIZER-BIONTECH
# 466              MODERNA
# 467              MODERNA
# 468              MODERNA
# 469              MODERNA
# 470              MODERNA
# 471              MODERNA
# 472              MODERNA
# 473              MODERNA
# 474      PFIZER-BIONTECH
# 475              MODERNA
# 476              MODERNA
# 477              MODERNA
# 478              MODERNA
# 479              MODERNA
# 480              MODERNA
# 481              MODERNA
# 482      PFIZER-BIONTECH
# 483              MODERNA
# 484      PFIZER-BIONTECH
# 485              MODERNA
# 486              MODERNA
# 491              MODERNA
# 492              MODERNA
# 493              MODERNA
# 495              MODERNA
# 496              MODERNA
# 497              MODERNA
# 498              MODERNA
# 499              MODERNA
# 503              MODERNA
# 504              MODERNA
# 505              MODERNA
# 506              MODERNA
# 507              MODERNA
# 508              MODERNA
# 509              MODERNA
# 510      PFIZER-BIONTECH
# 511      PFIZER-BIONTECH
# 512      PFIZER-BIONTECH
# 513      PFIZER-BIONTECH
# 514      PFIZER-BIONTECH
# 516      PFIZER-BIONTECH
# 519      PFIZER-BIONTECH
# 520      PFIZER-BIONTECH
# 521      PFIZER-BIONTECH
# 522      PFIZER-BIONTECH
# 523      PFIZER-BIONTECH
# 524      PFIZER-BIONTECH
# 525      PFIZER-BIONTECH
# 526      PFIZER-BIONTECH
# 527      PFIZER-BIONTECH
# 528      PFIZER-BIONTECH
# 529      PFIZER-BIONTECH
# 530      PFIZER-BIONTECH
# 531      PFIZER-BIONTECH
# 532      PFIZER-BIONTECH
# 533      PFIZER-BIONTECH
# 534      PFIZER-BIONTECH
# 535      PFIZER-BIONTECH
# 536      PFIZER-BIONTECH
# 537      PFIZER-BIONTECH
# 538      PFIZER-BIONTECH
# 539      PFIZER-BIONTECH
# 540      PFIZER-BIONTECH
# 541      PFIZER-BIONTECH
# 542      PFIZER-BIONTECH
# 543      PFIZER-BIONTECH
# 544      PFIZER-BIONTECH
# 546      PFIZER-BIONTECH
# 547      PFIZER-BIONTECH
# 548      PFIZER-BIONTECH
# 549      PFIZER-BIONTECH
# 550      PFIZER-BIONTECH
# 551      PFIZER-BIONTECH
# 553      PFIZER-BIONTECH
# 556      PFIZER-BIONTECH
# 557      PFIZER-BIONTECH
# 561      PFIZER-BIONTECH
# 563      PFIZER-BIONTECH
# 564      PFIZER-BIONTECH
# 565      PFIZER-BIONTECH
# 567      PFIZER-BIONTECH
# 568      PFIZER-BIONTECH
# 572      PFIZER-BIONTECH
# 573      PFIZER-BIONTECH
# 574      PFIZER-BIONTECH
# 575      PFIZER-BIONTECH
# 583      PFIZER-BIONTECH
# 584      PFIZER-BIONTECH
# 587      PFIZER-BIONTECH
# 588      PFIZER-BIONTECH
# 589      PFIZER-BIONTECH
# 592      PFIZER-BIONTECH
# 593      PFIZER-BIONTECH
# 594      PFIZER-BIONTECH
# 595      PFIZER-BIONTECH
# 598      PFIZER-BIONTECH
# 599      PFIZER-BIONTECH
# 600      PFIZER-BIONTECH
# 601      PFIZER-BIONTECH
# 602      PFIZER-BIONTECH
# 603      PFIZER-BIONTECH
# 604      PFIZER-BIONTECH
# 607      PFIZER-BIONTECH
# 608      PFIZER-BIONTECH
# 609      PFIZER-BIONTECH
# 610      PFIZER-BIONTECH
# 611      PFIZER-BIONTECH
# 613      PFIZER-BIONTECH
# 614      PFIZER-BIONTECH
# 615      PFIZER-BIONTECH
# 616      PFIZER-BIONTECH
# 617              MODERNA
# 618              MODERNA
# 619      PFIZER-BIONTECH
# 620      PFIZER-BIONTECH
# 621              MODERNA
# 622              MODERNA
# 623              MODERNA
# 624              MODERNA
# 625              MODERNA
# 626              MODERNA
# 627              MODERNA
# 628              MODERNA
# 629      PFIZER-BIONTECH
# 630      PFIZER-BIONTECH
# 631      PFIZER-BIONTECH
# 632              MODERNA
# 633      PFIZER-BIONTECH
# 634      PFIZER-BIONTECH
# 635      PFIZER-BIONTECH
# 636              MODERNA
# 637              MODERNA
# 638              MODERNA
# 639              MODERNA
# 640              MODERNA
# 641              MODERNA
# 642              MODERNA
# 643              MODERNA
# 644              MODERNA
# 645              MODERNA
# 648              MODERNA
# 649      PFIZER-BIONTECH
# 650              MODERNA
# 651      PFIZER-BIONTECH
# 652              MODERNA
# 653              MODERNA
# 654              MODERNA
# 655              MODERNA
# 656              MODERNA
# 657              MODERNA
# 658              MODERNA
# 659      PFIZER-BIONTECH
# 661      PFIZER-BIONTECH
# 662              MODERNA
# 663              MODERNA
# 664              MODERNA
# 665              MODERNA
# 666              MODERNA
# 667              MODERNA
# 668              MODERNA
# 669      PFIZER-BIONTECH
# 670      PFIZER-BIONTECH
# 671      PFIZER-BIONTECH
# 672      PFIZER-BIONTECH
# 673      PFIZER-BIONTECH
# 674      PFIZER-BIONTECH
# 680              MODERNA
# 681              MODERNA
# 682              MODERNA
# 683              MODERNA
# 684              MODERNA
# 685              MODERNA
# 686              MODERNA
# 687              MODERNA
# 688              MODERNA
# 689              MODERNA
# 690              MODERNA
# 691              MODERNA
# 692              MODERNA
# 693              MODERNA
# 694              MODERNA
# 695              MODERNA
# 696              MODERNA
# 697      PFIZER-BIONTECH
# 698              MODERNA
# 699      PFIZER-BIONTECH
# 700              MODERNA
# 701      PFIZER-BIONTECH
# 702              MODERNA
# 703              MODERNA
# 704              MODERNA
# 705              MODERNA
# 706      PFIZER-BIONTECH
# 707              MODERNA
# 708              MODERNA
# 709              MODERNA
# 710              MODERNA
# 711              MODERNA
# 712              MODERNA
# 713      PFIZER-BIONTECH
# 714      PFIZER-BIONTECH
# 715      PFIZER-BIONTECH
# 716      PFIZER-BIONTECH
# 717      PFIZER-BIONTECH
# 718      PFIZER-BIONTECH
# 719              MODERNA
# 720      PFIZER-BIONTECH
# 721      PFIZER-BIONTECH
# 722      PFIZER-BIONTECH
# 723      PFIZER-BIONTECH
# 724      PFIZER-BIONTECH
# 725      PFIZER-BIONTECH
# 726      PFIZER-BIONTECH
# 727      PFIZER-BIONTECH
# 728      PFIZER-BIONTECH
# 729      PFIZER-BIONTECH
# 730      PFIZER-BIONTECH
# 732      PFIZER-BIONTECH
# 735      PFIZER-BIONTECH
# 736      PFIZER-BIONTECH
# 737      PFIZER-BIONTECH
# 738      PFIZER-BIONTECH
# 740      PFIZER-BIONTECH
# 741      PFIZER-BIONTECH
# 742      PFIZER-BIONTECH
# 743      PFIZER-BIONTECH
# 744      PFIZER-BIONTECH
# 745      PFIZER-BIONTECH
# 746      PFIZER-BIONTECH
# 751              MODERNA
# 752              MODERNA
# 753              MODERNA
# 754              MODERNA
# 755      PFIZER-BIONTECH
# 756              MODERNA
# 757              MODERNA
# 758              MODERNA
# 759      PFIZER-BIONTECH
# 760      PFIZER-BIONTECH
# 761      PFIZER-BIONTECH
# 762      PFIZER-BIONTECH
# 763              MODERNA
# 764      PFIZER-BIONTECH
# 765      PFIZER-BIONTECH
# 766      PFIZER-BIONTECH
# 767      PFIZER-BIONTECH
# 768      PFIZER-BIONTECH
# 769      PFIZER-BIONTECH
# 770              MODERNA
# 771              MODERNA
# 772              MODERNA
# 773      PFIZER-BIONTECH
# 774      PFIZER-BIONTECH
# 775              MODERNA
# 776      PFIZER-BIONTECH
# 777      PFIZER-BIONTECH
# 778              MODERNA
# 779              MODERNA
# 780              MODERNA
# 781      PFIZER-BIONTECH
# 782      PFIZER-BIONTECH
# 783              MODERNA
# 784              MODERNA
# 785              MODERNA
# 786              MODERNA
# 787              MODERNA
# 788              MODERNA
# 789              MODERNA
# 790              MODERNA
# 791              MODERNA
# 792              MODERNA
# 793              MODERNA
# 794              MODERNA
# 795              MODERNA
# 796              MODERNA
# 797      PFIZER-BIONTECH
# 798      PFIZER-BIONTECH
# 799      PFIZER-BIONTECH
# 800      PFIZER-BIONTECH
# 801      PFIZER-BIONTECH
# 802      PFIZER-BIONTECH
# 803      PFIZER-BIONTECH
# 804      PFIZER-BIONTECH
# 805      PFIZER-BIONTECH
# 806      PFIZER-BIONTECH
# 807      PFIZER-BIONTECH
# 808      PFIZER-BIONTECH
# 809      PFIZER-BIONTECH
# 810      PFIZER-BIONTECH
# 811      PFIZER-BIONTECH
# 812      PFIZER-BIONTECH
# 813      PFIZER-BIONTECH
# 814      PFIZER-BIONTECH
# 815      PFIZER-BIONTECH
# 816      PFIZER-BIONTECH
# 817              MODERNA
# 818              MODERNA
# 819      PFIZER-BIONTECH
# 820      PFIZER-BIONTECH
# 821              MODERNA
# 822              MODERNA
# 823              MODERNA
# 824              MODERNA
# 825              MODERNA
# 826              MODERNA
# 827              MODERNA
# 828              MODERNA
# 829              MODERNA
# 830              MODERNA
# 831              MODERNA
# 832      PFIZER-BIONTECH
# 833      PFIZER-BIONTECH
# 834      PFIZER-BIONTECH
# 835              MODERNA
# 836              MODERNA
# 837      PFIZER-BIONTECH
# 838      PFIZER-BIONTECH
# 839              MODERNA
# 840              MODERNA
# 841              MODERNA
# 842              MODERNA
# 843              MODERNA
# 844              MODERNA
# 845      PFIZER-BIONTECH
# 846      PFIZER-BIONTECH
# 847      PFIZER-BIONTECH
# 848              MODERNA
# 849              MODERNA
# 850      PFIZER-BIONTECH
# 851      PFIZER-BIONTECH
# 852      PFIZER-BIONTECH
# 853      PFIZER-BIONTECH
# 854      PFIZER-BIONTECH
# 855      PFIZER-BIONTECH
# 856      PFIZER-BIONTECH
# 857              MODERNA
# 858      PFIZER-BIONTECH
# 859              MODERNA
# 861              MODERNA
# 863      PFIZER-BIONTECH
# 864      PFIZER-BIONTECH
# 865      PFIZER-BIONTECH
# 866              MODERNA
# 867      PFIZER-BIONTECH
# 868      PFIZER-BIONTECH
# 869      PFIZER-BIONTECH
# 870              MODERNA
# 871              MODERNA
# 872              MODERNA
# 873              MODERNA
# 874              MODERNA
# 875      PFIZER-BIONTECH
# 876      PFIZER-BIONTECH
# 877      PFIZER-BIONTECH
# 878      PFIZER-BIONTECH
# 879      PFIZER-BIONTECH
# 880      PFIZER-BIONTECH
# 881      PFIZER-BIONTECH
# 882      PFIZER-BIONTECH
# 883              MODERNA
# 884      PFIZER-BIONTECH
# 885      PFIZER-BIONTECH
# 886              MODERNA
# 887      PFIZER-BIONTECH
# 888      PFIZER-BIONTECH
# 889      PFIZER-BIONTECH
# 890      PFIZER-BIONTECH
# 891              MODERNA
# 892              MODERNA
# 893              MODERNA
# 894      PFIZER-BIONTECH
# 895      PFIZER-BIONTECH
# 896              MODERNA
# 897              MODERNA
# 898      PFIZER-BIONTECH
# 899      PFIZER-BIONTECH
# 900      PFIZER-BIONTECH
# 901      PFIZER-BIONTECH
# 902              MODERNA
# 903              MODERNA
# 904      PFIZER-BIONTECH
# 905      PFIZER-BIONTECH
# 906      PFIZER-BIONTECH
# 907              MODERNA
# 908              MODERNA
# 909      PFIZER-BIONTECH
# 910      PFIZER-BIONTECH
# 911              MODERNA
# 912      PFIZER-BIONTECH
# 913      PFIZER-BIONTECH
# 914      PFIZER-BIONTECH
# 915      PFIZER-BIONTECH
# 916      PFIZER-BIONTECH
# 917              MODERNA
# 918              MODERNA
# 919              MODERNA
# 920      PFIZER-BIONTECH
# 921      PFIZER-BIONTECH
# 922      PFIZER-BIONTECH
# 923              MODERNA
# 924      PFIZER-BIONTECH
# 925      PFIZER-BIONTECH
# 926      PFIZER-BIONTECH
# 927      PFIZER-BIONTECH
# 928      PFIZER-BIONTECH
# 929      PFIZER-BIONTECH
# 930      PFIZER-BIONTECH
# 931      PFIZER-BIONTECH
# 932      PFIZER-BIONTECH
# 933      PFIZER-BIONTECH
# 934      PFIZER-BIONTECH
# 935      PFIZER-BIONTECH
# 936      PFIZER-BIONTECH
# 937              MODERNA
# 938              MODERNA
# 939      PFIZER-BIONTECH
# 940      PFIZER-BIONTECH
# 941      PFIZER-BIONTECH
# 942              MODERNA
# 943      PFIZER-BIONTECH
# 944      PFIZER-BIONTECH
# 945      PFIZER-BIONTECH
# 946              MODERNA
# 947      PFIZER-BIONTECH
# 948      PFIZER-BIONTECH
# 949      PFIZER-BIONTECH
# 950      PFIZER-BIONTECH
# 951              MODERNA
# 952              MODERNA
# 953              MODERNA
# 954              MODERNA
# 955      PFIZER-BIONTECH
# 956      PFIZER-BIONTECH
# 957      PFIZER-BIONTECH
# 958      PFIZER-BIONTECH
# 959              MODERNA
# 960              MODERNA
# 961              MODERNA
# 963              MODERNA
# 964              MODERNA
# 965              MODERNA
# 966      PFIZER-BIONTECH
# 967      PFIZER-BIONTECH
# 968      PFIZER-BIONTECH
# 969      PFIZER-BIONTECH
# 970      PFIZER-BIONTECH
# 971      PFIZER-BIONTECH
# 972      PFIZER-BIONTECH
# 973              MODERNA
# 974      PFIZER-BIONTECH
# 975      PFIZER-BIONTECH
# 976      PFIZER-BIONTECH
# 977              MODERNA
# 978      PFIZER-BIONTECH
# 979      PFIZER-BIONTECH
# 980      PFIZER-BIONTECH
# 981      PFIZER-BIONTECH
# 982              MODERNA
# 983              MODERNA
# 984              MODERNA
# 985              MODERNA
# 986              MODERNA
# 987              MODERNA
# 988              MODERNA
# 989              MODERNA
# 990      PFIZER-BIONTECH
# 991      PFIZER-BIONTECH
# 992              MODERNA
# 993      PFIZER-BIONTECH
# 994      PFIZER-BIONTECH
# 995      PFIZER-BIONTECH
# 996              MODERNA
# 997      PFIZER-BIONTECH
# 998              MODERNA
# 999              MODERNA
# 1000             MODERNA
# 1001     PFIZER-BIONTECH
# 1002             MODERNA
# 1003             MODERNA
# 1004             MODERNA
# 1005             MODERNA
# 1006     PFIZER-BIONTECH
# 1007     PFIZER-BIONTECH
# 1008     PFIZER-BIONTECH
# 1009     PFIZER-BIONTECH
# 1010     PFIZER-BIONTECH
# 1011     PFIZER-BIONTECH
# 1012     PFIZER-BIONTECH
# 1013     PFIZER-BIONTECH
# 1014             MODERNA
# 1015     PFIZER-BIONTECH
# 1016             MODERNA
# 1017             MODERNA
# 1018             MODERNA
# 1019             MODERNA
# 1020             MODERNA
# 1021             MODERNA
# 1022             MODERNA
# 1023             MODERNA
# 1024     PFIZER-BIONTECH
# 1025             MODERNA
# 1026             MODERNA
# 1027             MODERNA
# 1028             MODERNA
# 1029             MODERNA
# 1030             MODERNA
# 1031     PFIZER-BIONTECH
# 1032     PFIZER-BIONTECH
# 1033             MODERNA
# 1034             MODERNA
# 1035             MODERNA
# 1036     PFIZER-BIONTECH
# 1037             MODERNA
# 1038             MODERNA
# 1039     PFIZER-BIONTECH
# 1040     PFIZER-BIONTECH
# 1041             MODERNA
# 1042             MODERNA
# 1043             MODERNA
# 1044             MODERNA
# 1045             MODERNA
# 1046     PFIZER-BIONTECH
# 1047     PFIZER-BIONTECH
# 1048             MODERNA
# 1049     PFIZER-BIONTECH
# 1050     PFIZER-BIONTECH
# 1051             MODERNA
# 1052             MODERNA
# 1053             MODERNA
# 1054             MODERNA
# 1055     PFIZER-BIONTECH
# 1056             MODERNA
# 1057             MODERNA
# 1058             MODERNA
# 1059             MODERNA
# 1060             MODERNA
# 1061             MODERNA
# 1062             MODERNA
# 1063             MODERNA
# 1064             MODERNA
# 1065             MODERNA
# 1069     PFIZER-BIONTECH
# 1073     PFIZER-BIONTECH
# 1074     PFIZER-BIONTECH
# 1075     PFIZER-BIONTECH
# 1076     PFIZER-BIONTECH
# 1079     PFIZER-BIONTECH
# 1080     PFIZER-BIONTECH
# 1081     PFIZER-BIONTECH
# 1083     PFIZER-BIONTECH
# 1084     PFIZER-BIONTECH
# 1085     PFIZER-BIONTECH
# 1086     PFIZER-BIONTECH
# 1087     PFIZER-BIONTECH
# 1088     PFIZER-BIONTECH
# 1089     PFIZER-BIONTECH
# 1090     PFIZER-BIONTECH
# 1091     PFIZER-BIONTECH
# 1093     PFIZER-BIONTECH
# 1094     PFIZER-BIONTECH
# 1095     PFIZER-BIONTECH
# 1096     PFIZER-BIONTECH
# 1097     PFIZER-BIONTECH
# 1098     PFIZER-BIONTECH
# 1099     PFIZER-BIONTECH
# 1100     PFIZER-BIONTECH
# 1101     PFIZER-BIONTECH
# 1102     PFIZER-BIONTECH
# 1103     PFIZER-BIONTECH
# 1104     PFIZER-BIONTECH
# 1105     PFIZER-BIONTECH
# 1107     PFIZER-BIONTECH
# 1108     PFIZER-BIONTECH
# 1111     PFIZER-BIONTECH
# 1112     PFIZER-BIONTECH
# 1115     PFIZER-BIONTECH
# 1116     PFIZER-BIONTECH
# 1117     PFIZER-BIONTECH
# 1118     PFIZER-BIONTECH
# 1133     PFIZER-BIONTECH
# 1136     PFIZER-BIONTECH
# 1137     PFIZER-BIONTECH
# 1138     PFIZER-BIONTECH
# 1139     PFIZER-BIONTECH
# 1142     PFIZER-BIONTECH
# 1143     PFIZER-BIONTECH
# 1145     PFIZER-BIONTECH
# 1146     PFIZER-BIONTECH
# 1149     PFIZER-BIONTECH
# 1156     PFIZER-BIONTECH
# 1157     PFIZER-BIONTECH
# 1166     PFIZER-BIONTECH
# 1167     PFIZER-BIONTECH
# 1168     PFIZER-BIONTECH
# 1169     PFIZER-BIONTECH
# 1170     PFIZER-BIONTECH
# 1172     PFIZER-BIONTECH
# 1173     PFIZER-BIONTECH
# 1176     PFIZER-BIONTECH
# 1177     PFIZER-BIONTECH
# 1178     PFIZER-BIONTECH
# 1179     PFIZER-BIONTECH
# 1180     PFIZER-BIONTECH
# 1181     PFIZER-BIONTECH
# 1182     PFIZER-BIONTECH
# 1183     PFIZER-BIONTECH
# 1184     PFIZER-BIONTECH
# 1185     PFIZER-BIONTECH
# 1186     PFIZER-BIONTECH
# 1187     PFIZER-BIONTECH
# 1188     PFIZER-BIONTECH
# 1189     PFIZER-BIONTECH
# 1190     PFIZER-BIONTECH
# 1191     PFIZER-BIONTECH
# 1192     PFIZER-BIONTECH
# 1193     PFIZER-BIONTECH
# 1194     PFIZER-BIONTECH
# 1195     PFIZER-BIONTECH
# 1196     PFIZER-BIONTECH
# 1197     PFIZER-BIONTECH
# 1203     PFIZER-BIONTECH
# 1204     PFIZER-BIONTECH
# 1205     PFIZER-BIONTECH
# 1206     PFIZER-BIONTECH
# 1209     PFIZER-BIONTECH
# 1210     PFIZER-BIONTECH
# 1213     PFIZER-BIONTECH
# 1214     PFIZER-BIONTECH
# 1215             MODERNA
# 1216             MODERNA
# 1217     PFIZER-BIONTECH
# 1218             MODERNA
# 1219             MODERNA
# 1220             MODERNA
# 1221             MODERNA
# 1232             MODERNA
# 1233             MODERNA
# 1234             MODERNA
# 1235     PFIZER-BIONTECH
# 1236     PFIZER-BIONTECH
# 1237     PFIZER-BIONTECH
# 1238     PFIZER-BIONTECH
# 1239     PFIZER-BIONTECH
# 1240             MODERNA
# 1241             MODERNA
# 1242     PFIZER-BIONTECH
# 1243     PFIZER-BIONTECH
# 1244             MODERNA
# 1245             MODERNA
# 1246             MODERNA
# 1247     PFIZER-BIONTECH
# 1248     PFIZER-BIONTECH
# 1249             MODERNA
# 1250             MODERNA
# 1251             MODERNA
# 1252     PFIZER-BIONTECH
# 1253             MODERNA
# 1254     PFIZER-BIONTECH
# 1255             MODERNA
# 1257     PFIZER-BIONTECH
# 1258     PFIZER-BIONTECH
# 1259     PFIZER-BIONTECH
# 1260             MODERNA
# 1261             MODERNA
# 1262     PFIZER-BIONTECH
# 1263             MODERNA
# 1264             MODERNA
# 1265             MODERNA
# 1266             MODERNA
# 1267             MODERNA
# 1268     PFIZER-BIONTECH
# 1269     PFIZER-BIONTECH
# 1270     PFIZER-BIONTECH
# 1271     PFIZER-BIONTECH
# 1272     PFIZER-BIONTECH
# 1273     PFIZER-BIONTECH
# 1274     PFIZER-BIONTECH
# 1275     PFIZER-BIONTECH
# 1276             MODERNA
# 1277     PFIZER-BIONTECH
# 1278     PFIZER-BIONTECH
# 1279             MODERNA
# 1280             MODERNA
# 1281     PFIZER-BIONTECH
# 1282     PFIZER-BIONTECH
# 1283     PFIZER-BIONTECH
# 1284     PFIZER-BIONTECH
# 1285     PFIZER-BIONTECH
# 1287             MODERNA
# 1288             MODERNA
# 1289             MODERNA
# 1290             MODERNA
# 1291     PFIZER-BIONTECH
# 1292     PFIZER-BIONTECH
# 1293     PFIZER-BIONTECH
# 1294             MODERNA
# 1295     PFIZER-BIONTECH
# 1296     PFIZER-BIONTECH
# 1297     PFIZER-BIONTECH
# 1298     PFIZER-BIONTECH
# 1299             MODERNA
# 1300             MODERNA
# 1301     PFIZER-BIONTECH
# 1302     PFIZER-BIONTECH
# 1303     PFIZER-BIONTECH
# 1304     PFIZER-BIONTECH
# 1305     PFIZER-BIONTECH
# 1306     PFIZER-BIONTECH
# 1307     PFIZER-BIONTECH
# 1308     PFIZER-BIONTECH
# 1309             MODERNA
# 1310             MODERNA
# 1311             MODERNA
# 1312     PFIZER-BIONTECH
# 1313     PFIZER-BIONTECH
# 1314             MODERNA
# 1315             MODERNA
# 1316             MODERNA
# 1317             MODERNA
# 1318             MODERNA
# 1319     PFIZER-BIONTECH
# 1320     PFIZER-BIONTECH
# 1321             MODERNA
# 1322             MODERNA
# 1323             MODERNA
# 1324     PFIZER-BIONTECH
# 1325     PFIZER-BIONTECH
# 1326     PFIZER-BIONTECH
# 1327     PFIZER-BIONTECH
# 1328             MODERNA
# 1329     PFIZER-BIONTECH
# 1330     PFIZER-BIONTECH
# 1331             MODERNA
# 1332             MODERNA
# 1333     PFIZER-BIONTECH
# 1334             MODERNA
# 1335     PFIZER-BIONTECH
# 1336             MODERNA
# 1337     PFIZER-BIONTECH
# 1338     PFIZER-BIONTECH
# 1339             MODERNA
# 1340     PFIZER-BIONTECH
# 1341     PFIZER-BIONTECH
# 1342     PFIZER-BIONTECH
# 1343     PFIZER-BIONTECH
# 1344             MODERNA
# 1345             MODERNA
# 1348             MODERNA
# 1349             MODERNA
# 1350             MODERNA
# 1351             MODERNA
# 1352             MODERNA
# 1353             MODERNA
# 1354     PFIZER-BIONTECH
# 1355     PFIZER-BIONTECH
# 1356     PFIZER-BIONTECH
# 1357             MODERNA
# 1358     PFIZER-BIONTECH
# 1359     PFIZER-BIONTECH
# 1360     PFIZER-BIONTECH
# 1361     PFIZER-BIONTECH
# 1362     PFIZER-BIONTECH
# 1363             MODERNA
# 1364             MODERNA
# 1365             MODERNA
# 1366     PFIZER-BIONTECH
# 1367     PFIZER-BIONTECH
# 1368     PFIZER-BIONTECH
# 1369     PFIZER-BIONTECH
# 1370     PFIZER-BIONTECH
# 1371             MODERNA
# 1372             MODERNA
# 1373             MODERNA
# 1374             MODERNA
# 1375             MODERNA
# 1376     PFIZER-BIONTECH
# 1377     PFIZER-BIONTECH
# 1378     PFIZER-BIONTECH
# 1379     PFIZER-BIONTECH
# 1380     PFIZER-BIONTECH
# 1381             MODERNA
# 1382             MODERNA
# 1383     PFIZER-BIONTECH
# 1384             MODERNA
# 1385             MODERNA
# 1386     PFIZER-BIONTECH
# 1387     PFIZER-BIONTECH
# 1388     PFIZER-BIONTECH
# 1389     PFIZER-BIONTECH
# 1390             MODERNA
# 1391             MODERNA
# 1392     PFIZER-BIONTECH
# 1393     PFIZER-BIONTECH
# 1394     PFIZER-BIONTECH
# 1395     PFIZER-BIONTECH
# 1396     PFIZER-BIONTECH
# 1397     PFIZER-BIONTECH
# 1398     PFIZER-BIONTECH
# 1399     PFIZER-BIONTECH
# 1400     PFIZER-BIONTECH
# 1401     PFIZER-BIONTECH
# 1402     PFIZER-BIONTECH
# 1403     PFIZER-BIONTECH
# 1404             MODERNA
# 1405             MODERNA
# 1406             MODERNA
# 1407             MODERNA
# 1408     PFIZER-BIONTECH
# 1409     PFIZER-BIONTECH
# 1410             MODERNA
# 1411     PFIZER-BIONTECH
# 1412     PFIZER-BIONTECH
# 1413             MODERNA
# 1414             MODERNA
# 1415             MODERNA
# 1416             MODERNA
# 1417             MODERNA
# 1418             MODERNA
# 1419             MODERNA
# 1420             MODERNA
# 1421     PFIZER-BIONTECH
# 1422     PFIZER-BIONTECH
# 1423             MODERNA
# 1424     PFIZER-BIONTECH
# 1425             MODERNA
# 1426             MODERNA
# 1427     PFIZER-BIONTECH
# 1428     PFIZER-BIONTECH
# 1429     PFIZER-BIONTECH
# 1430             MODERNA
# 1431             MODERNA
# 1432             MODERNA
# 1434     PFIZER-BIONTECH
# 1435     PFIZER-BIONTECH
# 1436     PFIZER-BIONTECH
# 1437     PFIZER-BIONTECH
# 1438     PFIZER-BIONTECH
# 1439     PFIZER-BIONTECH
# 1440     PFIZER-BIONTECH
# 1441     PFIZER-BIONTECH
# 1442     PFIZER-BIONTECH
# 1443     PFIZER-BIONTECH
# 1444     PFIZER-BIONTECH
# 1445     PFIZER-BIONTECH
# 1446     PFIZER-BIONTECH
# 1447     PFIZER-BIONTECH
# 1448     PFIZER-BIONTECH
# 1449     PFIZER-BIONTECH
# 1450     PFIZER-BIONTECH
# 1456     PFIZER-BIONTECH
# 1457     PFIZER-BIONTECH
# 1458     PFIZER-BIONTECH
# 1459     PFIZER-BIONTECH
# 1460     PFIZER-BIONTECH
# 1461     PFIZER-BIONTECH
# 1462             MODERNA
# 1463     PFIZER-BIONTECH
# 1464             MODERNA
# 1465             MODERNA
# 1466             MODERNA
# 1467             MODERNA
# 1468             MODERNA
# 1469             MODERNA
# 1470             MODERNA
# 1471             MODERNA
# 1472             MODERNA
# 1473             MODERNA
# 1474             MODERNA
# 1475     PFIZER-BIONTECH
# 1476             MODERNA
# 1477             MODERNA
# 1478             MODERNA
# 1479             MODERNA
# 1480             MODERNA
# 1481     PFIZER-BIONTECH
# 1482     PFIZER-BIONTECH
# 1483             MODERNA
# 1486             MODERNA
# 1487             MODERNA
# 1488             MODERNA
# 1490             UNKNOWN
# 1492     PFIZER-BIONTECH
# 1493     PFIZER-BIONTECH
# 1494     PFIZER-BIONTECH
# 1495     PFIZER-BIONTECH
# 1496     PFIZER-BIONTECH
# 1497     PFIZER-BIONTECH
# 1498     PFIZER-BIONTECH
# 1499     PFIZER-BIONTECH
# 1500     PFIZER-BIONTECH
# 1501     PFIZER-BIONTECH
# 1502     PFIZER-BIONTECH
# 1505     PFIZER-BIONTECH
# 1506     PFIZER-BIONTECH
# 1507     PFIZER-BIONTECH
# 1508     PFIZER-BIONTECH
# 1509     PFIZER-BIONTECH
# 1515     PFIZER-BIONTECH
# 1516     PFIZER-BIONTECH
# 1517     PFIZER-BIONTECH
# 1518     PFIZER-BIONTECH
# 1519             MODERNA
# 1520             MODERNA
# 1521             MODERNA
# 1522             MODERNA
# 1523             MODERNA
# 1524             MODERNA
# 1525             MODERNA
# 1526             MODERNA
# 1531     PFIZER-BIONTECH
# 1532     PFIZER-BIONTECH
# 1533     PFIZER-BIONTECH
# 1534     PFIZER-BIONTECH
# 1535     PFIZER-BIONTECH
# 1536     PFIZER-BIONTECH
# 1537     PFIZER-BIONTECH
# 1538     PFIZER-BIONTECH
# 1539     PFIZER-BIONTECH
# 1540     PFIZER-BIONTECH
# 1541     PFIZER-BIONTECH
# 1542     PFIZER-BIONTECH
# 1543     PFIZER-BIONTECH
# 1544     PFIZER-BIONTECH
# 1545     PFIZER-BIONTECH
# 1546     PFIZER-BIONTECH
# 1547     PFIZER-BIONTECH
# 1548             MODERNA
# 1549             MODERNA
# 1550             MODERNA
# 1551             MODERNA
# 1552             MODERNA
# 1553     PFIZER-BIONTECH
# 1554     PFIZER-BIONTECH
# 1555     PFIZER-BIONTECH
# 1556     PFIZER-BIONTECH
# 1557     PFIZER-BIONTECH
# 1558             MODERNA
# 1559             MODERNA
# 1560             MODERNA
# 1561     PFIZER-BIONTECH
# 1562     PFIZER-BIONTECH
# 1563     PFIZER-BIONTECH
# 1564             MODERNA
# 1565             MODERNA
# 1566             MODERNA
# 1567             MODERNA
# 1568             MODERNA
# 1569             MODERNA
# 1570     PFIZER-BIONTECH
# 1571     PFIZER-BIONTECH
# 1572     PFIZER-BIONTECH
# 1573             MODERNA
# 1574             MODERNA
# 1575             MODERNA
# 1576             MODERNA
# 1577             MODERNA
# 1578             MODERNA
# 1579             MODERNA
# 1580             MODERNA
# 1581     PFIZER-BIONTECH
# 1582     PFIZER-BIONTECH
# 1583     PFIZER-BIONTECH
# 1584     PFIZER-BIONTECH
# 1585     PFIZER-BIONTECH
# 1586     PFIZER-BIONTECH
# 1587     PFIZER-BIONTECH
# 1588             MODERNA
# 1589             MODERNA
# 1590     PFIZER-BIONTECH
# 1591             MODERNA
# 1592             MODERNA
# 1593             MODERNA
# 1594             MODERNA
# 1595             MODERNA
# 1596     PFIZER-BIONTECH
# 1597     PFIZER-BIONTECH
# 1598             MODERNA
# 1599             MODERNA
# 1600     PFIZER-BIONTECH
# 1601     PFIZER-BIONTECH
# 1602     PFIZER-BIONTECH
# 1603             MODERNA
# 1604     PFIZER-BIONTECH
# 1605     PFIZER-BIONTECH
# 1606             MODERNA
# 1607     PFIZER-BIONTECH
# 1608     PFIZER-BIONTECH
# 1609     PFIZER-BIONTECH
# 1610     PFIZER-BIONTECH
# 1611             MODERNA
# 1612             MODERNA
# 1613             MODERNA
# 1614             MODERNA
# 1615     PFIZER-BIONTECH
# 1616     PFIZER-BIONTECH
# 1617     PFIZER-BIONTECH
# 1618     PFIZER-BIONTECH
# 1619     PFIZER-BIONTECH
# 1620     PFIZER-BIONTECH
# 1621     PFIZER-BIONTECH
# 1622     PFIZER-BIONTECH
# 1623             MODERNA
# 1624             MODERNA
# 1625             MODERNA
# 1626     PFIZER-BIONTECH
# 1627     PFIZER-BIONTECH
# 1628     PFIZER-BIONTECH
# 1629     PFIZER-BIONTECH
# 1630     PFIZER-BIONTECH
# 1631     PFIZER-BIONTECH
# 1632     PFIZER-BIONTECH
# 1634             MODERNA
# 1635             MODERNA
# 1637             MODERNA
# 1638             MODERNA
# 1639     PFIZER-BIONTECH
# 1640             MODERNA
# 1641             MODERNA
# 1642             MODERNA
# 1643             MODERNA
# 1644             MODERNA
# 1645             MODERNA
# 1646             MODERNA
# 1647             MODERNA
# 1648             MODERNA
# 1649             MODERNA
# 1650             MODERNA
# 1651             MODERNA
# 1652     PFIZER-BIONTECH
# 1653     PFIZER-BIONTECH
# 1654             MODERNA
# 1655             MODERNA
# 1656             MODERNA
# 1657             MODERNA
# 1658             MODERNA
# 1659     PFIZER-BIONTECH
# 1660             MODERNA
# 1661     PFIZER-BIONTECH
# 1662             MODERNA
# 1663             MODERNA
# 1664             MODERNA
# 1665             MODERNA
# 1666             MODERNA
# 1667     PFIZER-BIONTECH
# 1668     PFIZER-BIONTECH
# 1669     PFIZER-BIONTECH
# 1670     PFIZER-BIONTECH
# 1671     PFIZER-BIONTECH
# 1672     PFIZER-BIONTECH
# 1673     PFIZER-BIONTECH
# 1674     PFIZER-BIONTECH
# 1675             MODERNA
# 1676             MODERNA
# 1677     PFIZER-BIONTECH
# 1678     PFIZER-BIONTECH
# 1679             MODERNA
# 1680             MODERNA
# 1681             MODERNA
# 1682             MODERNA
# 1683             MODERNA
# 1684             MODERNA
# 1685     PFIZER-BIONTECH
# 1686     PFIZER-BIONTECH
# 1687             MODERNA
# 1688             MODERNA
# 1689             MODERNA
# 1690             MODERNA
# 1691             MODERNA
# 1692             MODERNA
# 1693             MODERNA
# 1694             MODERNA
# 1695             MODERNA
# 1696             MODERNA
# 1697     PFIZER-BIONTECH
# 1698             MODERNA
# 1699             MODERNA
# 1700             MODERNA
# 1701             MODERNA
# 1702     PFIZER-BIONTECH
# 1703     PFIZER-BIONTECH
# 1704     PFIZER-BIONTECH
# 1705     PFIZER-BIONTECH
# 1706             MODERNA
# 1707             MODERNA
# 1708             MODERNA
# 1709             MODERNA
# 1710             MODERNA
# 1711             MODERNA
# 1712     PFIZER-BIONTECH
# 1713             MODERNA
# 1714             MODERNA
# 1715             MODERNA
# 1717             MODERNA
# 1722             MODERNA
# 1723             MODERNA
# 1724             MODERNA
# 1725             MODERNA
# 1726             MODERNA
# 1727     PFIZER-BIONTECH
# 1728     PFIZER-BIONTECH
# 1729     PFIZER-BIONTECH
# 1730     PFIZER-BIONTECH
# 1731     PFIZER-BIONTECH
# 1732     PFIZER-BIONTECH
# 1736     PFIZER-BIONTECH
# 1737     PFIZER-BIONTECH
# 1738     PFIZER-BIONTECH
# 1739     PFIZER-BIONTECH
# 1740     PFIZER-BIONTECH
# 1741     PFIZER-BIONTECH
# 1742     PFIZER-BIONTECH
# 1743     PFIZER-BIONTECH
# 1744     PFIZER-BIONTECH
# 1745     PFIZER-BIONTECH
# 1746     PFIZER-BIONTECH
# 1747     PFIZER-BIONTECH
# 1748     PFIZER-BIONTECH
# 1749     PFIZER-BIONTECH
# 1750     PFIZER-BIONTECH
# 1751     PFIZER-BIONTECH
# 1752     PFIZER-BIONTECH
# 1753     PFIZER-BIONTECH
# 1754     PFIZER-BIONTECH
# 1755     PFIZER-BIONTECH
# 1756     PFIZER-BIONTECH
# 1757     PFIZER-BIONTECH
# 1758     PFIZER-BIONTECH
# 1759     PFIZER-BIONTECH
# 1760     PFIZER-BIONTECH
# 1761     PFIZER-BIONTECH
# 1762     PFIZER-BIONTECH
# 1763     PFIZER-BIONTECH
# 1764     PFIZER-BIONTECH
# 1765     PFIZER-BIONTECH
# 1766     PFIZER-BIONTECH
# 1768     PFIZER-BIONTECH
# 1769     PFIZER-BIONTECH
# 1772     PFIZER-BIONTECH
# 1773     PFIZER-BIONTECH
# 1774     PFIZER-BIONTECH
# 1775     PFIZER-BIONTECH
# 1776     PFIZER-BIONTECH
# 1777     PFIZER-BIONTECH
# 1778     PFIZER-BIONTECH
# 1779     PFIZER-BIONTECH
# 1780     PFIZER-BIONTECH
# 1781     PFIZER-BIONTECH
# 1782     PFIZER-BIONTECH
# 1783     PFIZER-BIONTECH
# 1784     PFIZER-BIONTECH
# 1785     PFIZER-BIONTECH
# 1786     PFIZER-BIONTECH
# 1787     PFIZER-BIONTECH
# 1790             MODERNA
# 1791             MODERNA
# 1792             MODERNA
# 1793             MODERNA
# 1794             MODERNA
# 1795             MODERNA
# 1797             MODERNA
# 1798     PFIZER-BIONTECH
# 1799     PFIZER-BIONTECH
# 1800     PFIZER-BIONTECH
# 1801     PFIZER-BIONTECH
# 1802             MODERNA
# 1803     PFIZER-BIONTECH
# 1804             MODERNA
# 1805             MODERNA
# 1806             MODERNA
# 1807             MODERNA
# 1808             MODERNA
# 1809             MODERNA
# 1810             MODERNA
# 1811             MODERNA
# 1812             MODERNA
# 1813             MODERNA
# 1814             MODERNA
# 1815             MODERNA
# 1816             MODERNA
# 1817             MODERNA
# 1818     PFIZER-BIONTECH
# 1819             UNKNOWN
# 1820             UNKNOWN
# 1821             UNKNOWN
# 1822     PFIZER-BIONTECH
# 1823     PFIZER-BIONTECH
# 1824     PFIZER-BIONTECH
# 1825     PFIZER-BIONTECH
# 1826     PFIZER-BIONTECH
# 1827             MODERNA
# 1828             MODERNA
# 1829             MODERNA
# 1830             MODERNA
# 1831             MODERNA
# 1832     PFIZER-BIONTECH
# 1833     PFIZER-BIONTECH
# 1834     PFIZER-BIONTECH
# 1835             MODERNA
# 1836     PFIZER-BIONTECH
# 1837             MODERNA
# 1838     PFIZER-BIONTECH
# 1839             MODERNA
# 1840             MODERNA
# 1841             MODERNA
# 1842             MODERNA
# 1843     PFIZER-BIONTECH
# 1844     PFIZER-BIONTECH
# 1845     PFIZER-BIONTECH
# 1846             MODERNA
# 1847             MODERNA
# 1848             MODERNA
# 1849             MODERNA
# 1850             MODERNA
# 1851     PFIZER-BIONTECH
# 1852     PFIZER-BIONTECH
# 1853             MODERNA
# 1854             MODERNA
# 1855             MODERNA
# 1856             MODERNA
# 1857             MODERNA
# 1858             MODERNA
# 1859             MODERNA
# 1860     PFIZER-BIONTECH
# 1861             MODERNA
# 1862             MODERNA
# 1863             MODERNA
# 1864             MODERNA
# 1865             MODERNA
# 1866             MODERNA
# 1867             MODERNA
# 1868             MODERNA
# 1869             MODERNA
# 1870             MODERNA
# 1871             MODERNA
# 1872             MODERNA
# 1873             MODERNA
# 1874     PFIZER-BIONTECH
# 1875             MODERNA
# 1876             MODERNA
# 1877             MODERNA
# 1878     PFIZER-BIONTECH
# 1879             MODERNA
# 1880             MODERNA
# 1881             MODERNA
# 1884             MODERNA
# 1886     PFIZER-BIONTECH
# 1888     PFIZER-BIONTECH
# 1889     PFIZER-BIONTECH
# 1890     PFIZER-BIONTECH
# 1891     PFIZER-BIONTECH
# 1892     PFIZER-BIONTECH
# 1893     PFIZER-BIONTECH
# 1894     PFIZER-BIONTECH
# 1895     PFIZER-BIONTECH
# 1896     PFIZER-BIONTECH
# 1897     PFIZER-BIONTECH
# 1898     PFIZER-BIONTECH
# 1899     PFIZER-BIONTECH
# 1900     PFIZER-BIONTECH
# 1901     PFIZER-BIONTECH
# 1902     PFIZER-BIONTECH
# 1903     PFIZER-BIONTECH
# 1906     PFIZER-BIONTECH
# 1907     PFIZER-BIONTECH
# 1908     PFIZER-BIONTECH
# 1913     PFIZER-BIONTECH
# 1915     PFIZER-BIONTECH
# 1916             MODERNA
# 1917             MODERNA
# 1918             MODERNA
# 1919             MODERNA
# 1920             MODERNA
# 1921             MODERNA
# 1922             MODERNA
# 1923     PFIZER-BIONTECH
# 1924     PFIZER-BIONTECH
# 1925     PFIZER-BIONTECH
# 1926     PFIZER-BIONTECH
# 1927     PFIZER-BIONTECH
# 1928     PFIZER-BIONTECH
# 1929             MODERNA
# 1930             MODERNA
# 1931     PFIZER-BIONTECH
# 1932     PFIZER-BIONTECH
# 1933             MODERNA
# 1934             MODERNA
# 1935             MODERNA
# 1936             MODERNA
# 1937             MODERNA
# 1938             MODERNA
# 1939             MODERNA
# 1940             MODERNA
# 1941     PFIZER-BIONTECH
# 1942     PFIZER-BIONTECH
# 1943     PFIZER-BIONTECH
# 1944             MODERNA
# 1945             MODERNA
# 1946             MODERNA
# 1947             MODERNA
# 1948     PFIZER-BIONTECH
# 1949             MODERNA
# 1950             MODERNA
# 1951             MODERNA
# 1952             MODERNA
# 1953             MODERNA
# 1954             MODERNA
# 1955             MODERNA
# 1956             MODERNA
# 1961             MODERNA
# 1962     PFIZER-BIONTECH
# 1963     PFIZER-BIONTECH
# 1964     PFIZER-BIONTECH
# 1965     PFIZER-BIONTECH
# 1966     PFIZER-BIONTECH
# 1967     PFIZER-BIONTECH
# 1968     PFIZER-BIONTECH
# 1969     PFIZER-BIONTECH
# 1970     PFIZER-BIONTECH
# 1971     PFIZER-BIONTECH
# 1972     PFIZER-BIONTECH
# 1973     PFIZER-BIONTECH
# 1974     PFIZER-BIONTECH
# 1975     PFIZER-BIONTECH
# 1978     PFIZER-BIONTECH
# 1979     PFIZER-BIONTECH
# 1981     PFIZER-BIONTECH
# 1982     PFIZER-BIONTECH
# 1983     PFIZER-BIONTECH
# 1984     PFIZER-BIONTECH
# 1985     PFIZER-BIONTECH
# 1986     PFIZER-BIONTECH
# 1987     PFIZER-BIONTECH
# 1989     PFIZER-BIONTECH
# 1991     PFIZER-BIONTECH
# 1992     PFIZER-BIONTECH
# 1993     PFIZER-BIONTECH
# 1994     PFIZER-BIONTECH
# 1995     PFIZER-BIONTECH
# 1998     PFIZER-BIONTECH
# 2000     PFIZER-BIONTECH
# 2001     PFIZER-BIONTECH
# 2002     PFIZER-BIONTECH
# 2003     PFIZER-BIONTECH
# 2004     PFIZER-BIONTECH
# 2005     PFIZER-BIONTECH
# 2006     PFIZER-BIONTECH
# 2007             MODERNA
# 2008             MODERNA
# 2009             MODERNA
# 2010             MODERNA
# 2011             MODERNA
# 2012     PFIZER-BIONTECH
# 2013     PFIZER-BIONTECH
# 2014     PFIZER-BIONTECH
# 2015     PFIZER-BIONTECH
# 2016     PFIZER-BIONTECH
# 2017             MODERNA
# 2018             MODERNA
# 2019     PFIZER-BIONTECH
# 2020     PFIZER-BIONTECH
# 2021     PFIZER-BIONTECH
# 2022     PFIZER-BIONTECH
# 2023     PFIZER-BIONTECH
# 2024             MODERNA
# 2025             MODERNA
# 2026             MODERNA
# 2027             MODERNA
# 2028             MODERNA
# 2029             MODERNA
# 2030             MODERNA
# 2031             MODERNA
# 2032     PFIZER-BIONTECH
# 2033     PFIZER-BIONTECH
# 2034     PFIZER-BIONTECH
# 2035     PFIZER-BIONTECH
# 2036     PFIZER-BIONTECH
# 2037             MODERNA
# 2038             MODERNA
# 2039             MODERNA
# 2040     PFIZER-BIONTECH
# 2041             MODERNA
# 2042             MODERNA
# 2043             MODERNA
# 2044     PFIZER-BIONTECH
# 2045     PFIZER-BIONTECH
# 2046     PFIZER-BIONTECH
# 2047             MODERNA
# 2048     PFIZER-BIONTECH
# 2049     PFIZER-BIONTECH
# 2050             MODERNA
# 2051     PFIZER-BIONTECH
# 2052             MODERNA
# 2053             MODERNA
# 2054             MODERNA
# 2055     PFIZER-BIONTECH
# 2056     PFIZER-BIONTECH
# 2057     PFIZER-BIONTECH
# 2058             MODERNA
# 2059             MODERNA
# 2060             MODERNA
# 2061             MODERNA
# 2062             MODERNA
# 2063     PFIZER-BIONTECH
# 2064             MODERNA
# 2065             MODERNA
# 2066             MODERNA
# 2067             MODERNA
# 2068             MODERNA
# 2069             MODERNA
# 2070             MODERNA
# 2071             MODERNA
# 2072     PFIZER-BIONTECH
# 2073             MODERNA
# 2074             MODERNA
# 2075     PFIZER-BIONTECH
# 2076     PFIZER-BIONTECH
# 2077     PFIZER-BIONTECH
# 2078     PFIZER-BIONTECH
# 2079     PFIZER-BIONTECH
# 2080             MODERNA
# 2081             MODERNA
# 2082             MODERNA
# 2083     PFIZER-BIONTECH
# 2084     PFIZER-BIONTECH
# 2085     PFIZER-BIONTECH
# 2086     PFIZER-BIONTECH
# 2087             MODERNA
# 2088             MODERNA
# 2089             MODERNA
# 2090             MODERNA
# 2091             MODERNA
# 2092             MODERNA
# 2093             MODERNA
# 2094             MODERNA
# 2095             MODERNA
# 2096             MODERNA
# 2097             MODERNA
# 2098             MODERNA
# 2099             MODERNA
# 2100             MODERNA
# 2101     PFIZER-BIONTECH
# 2102     PFIZER-BIONTECH
# 2103     PFIZER-BIONTECH
# 2104     PFIZER-BIONTECH
# 2105             MODERNA
# 2106             MODERNA
# 2107             MODERNA
# 2108             MODERNA
# 2109             MODERNA
# 2110             MODERNA
# 2111             MODERNA
# 2112             MODERNA
# 2113             MODERNA
# 2114             MODERNA
# 2115             MODERNA
# 2116             MODERNA
# 2117             MODERNA
# 2118             MODERNA
# 2119             MODERNA
# 2120             MODERNA
# 2121             MODERNA
# 2122             MODERNA
# 2123             MODERNA
# 2124     PFIZER-BIONTECH
# 2125     PFIZER-BIONTECH
# 2126             MODERNA
# 2127     PFIZER-BIONTECH
# 2128     PFIZER-BIONTECH
# 2129     PFIZER-BIONTECH
# 2132             MODERNA
# 2133     PFIZER-BIONTECH
# 2134     PFIZER-BIONTECH
# 2135     PFIZER-BIONTECH
# 2136     PFIZER-BIONTECH
# 2137     PFIZER-BIONTECH
# 2138     PFIZER-BIONTECH
# 2139     PFIZER-BIONTECH
# 2141     PFIZER-BIONTECH
# 2142     PFIZER-BIONTECH
# 2143     PFIZER-BIONTECH
# 2144     PFIZER-BIONTECH
# 2146     PFIZER-BIONTECH
# 2147     PFIZER-BIONTECH
# 2148     PFIZER-BIONTECH
# 2149     PFIZER-BIONTECH
# 2150     PFIZER-BIONTECH
# 2151     PFIZER-BIONTECH
# 2152             MODERNA
# 2153             MODERNA
# 2155     PFIZER-BIONTECH
# 2156     PFIZER-BIONTECH
# 2157     PFIZER-BIONTECH
# 2158     PFIZER-BIONTECH
# 2159     PFIZER-BIONTECH
# 2160             MODERNA
# 2161             MODERNA
# 2162             MODERNA
# 2163     PFIZER-BIONTECH
# 2164     PFIZER-BIONTECH
# 2166             MODERNA
# 2167     PFIZER-BIONTECH
# 2168             MODERNA
# 2169             MODERNA
# 2172     PFIZER-BIONTECH
# 2173             MODERNA
# 2174     PFIZER-BIONTECH
# 2176             MODERNA
# 2184             MODERNA
# 2185             MODERNA
# 2188     PFIZER-BIONTECH
# 2189     PFIZER-BIONTECH
# 2190     PFIZER-BIONTECH
# 2191     PFIZER-BIONTECH
# 2195     PFIZER-BIONTECH
# 2201     PFIZER-BIONTECH
# 2206     PFIZER-BIONTECH
# 2207     PFIZER-BIONTECH
# 2208     PFIZER-BIONTECH
# 2209     PFIZER-BIONTECH
# 2216     PFIZER-BIONTECH
# 2217     PFIZER-BIONTECH
# 2218     PFIZER-BIONTECH
# 2219     PFIZER-BIONTECH
# 2220     PFIZER-BIONTECH
# 2223     PFIZER-BIONTECH
# 2227     PFIZER-BIONTECH
# 2228     PFIZER-BIONTECH
# 2229     PFIZER-BIONTECH
# 2230     PFIZER-BIONTECH
# 2231     PFIZER-BIONTECH
# 2232     PFIZER-BIONTECH
# ...
# 39552            MODERNA
# 39553            MODERNA
# 39554            MODERNA
# 39555            MODERNA
# 39556            MODERNA
# 39557            MODERNA
# 39558            MODERNA
# 39559            MODERNA
# 39560            MODERNA
# 39561            MODERNA
# 39562            MODERNA
# 39563    PFIZER-BIONTECH
# 39564            MODERNA
# 39565            MODERNA
# 39566            MODERNA
# 39567    PFIZER-BIONTECH
# 39568    PFIZER-BIONTECH
# 39569    PFIZER-BIONTECH
# 39570            MODERNA
# 39571            MODERNA
# 39572    PFIZER-BIONTECH
# 39573    PFIZER-BIONTECH
# 39574    PFIZER-BIONTECH
# 39575    PFIZER-BIONTECH
# 39576            MODERNA
# 39577            MODERNA
# 39578            MODERNA
# 39579    PFIZER-BIONTECH
# 39580            MODERNA
# 39581            MODERNA
# 39582            MODERNA
# 39583            MODERNA
# 39584            MODERNA
# 39585            MODERNA
# 39586            MODERNA
# 39587            MODERNA
# 39588            MODERNA
# 39589            MODERNA
# 39590    PFIZER-BIONTECH
# 39591    PFIZER-BIONTECH
# 39592    PFIZER-BIONTECH
# 39593    PFIZER-BIONTECH
# 39594    PFIZER-BIONTECH
# 39595    PFIZER-BIONTECH
# 39596    PFIZER-BIONTECH
# 39598    PFIZER-BIONTECH
# 39599    PFIZER-BIONTECH
# 39600    PFIZER-BIONTECH
# 39601    PFIZER-BIONTECH
# 39603    PFIZER-BIONTECH
# 39604    PFIZER-BIONTECH
# 39605            MODERNA
# 39606    PFIZER-BIONTECH
# 39607    PFIZER-BIONTECH
# 39608    PFIZER-BIONTECH
# 39609    PFIZER-BIONTECH
# 39610    PFIZER-BIONTECH
# 39611    PFIZER-BIONTECH
# 39612            MODERNA
# 39613            MODERNA
# 39614            MODERNA
# 39615            MODERNA
# 39616            MODERNA
# 39617    PFIZER-BIONTECH
# 39618    PFIZER-BIONTECH
# 39619    PFIZER-BIONTECH
# 39620            MODERNA
# 39621            MODERNA
# 39622            MODERNA
# 39623    PFIZER-BIONTECH
# 39624    PFIZER-BIONTECH
# 39625    PFIZER-BIONTECH
# 39626    PFIZER-BIONTECH
# 39627            MODERNA
# 39628            MODERNA
# 39629            MODERNA
# 39630            MODERNA
# 39631    PFIZER-BIONTECH
# 39632    PFIZER-BIONTECH
# 39633            MODERNA
# 39634    PFIZER-BIONTECH
# 39635    PFIZER-BIONTECH
# 39636    PFIZER-BIONTECH
# 39637    PFIZER-BIONTECH
# 39638    PFIZER-BIONTECH
# 39639            MODERNA
# 39640            MODERNA
# 39641            MODERNA
# 39642            MODERNA
# 39643            MODERNA
# 39646            MODERNA
# 39649    PFIZER-BIONTECH
# 39650    PFIZER-BIONTECH
# 39651    PFIZER-BIONTECH
# 39652    PFIZER-BIONTECH
# 39653    PFIZER-BIONTECH
# 39655            MODERNA
# 39656            MODERNA
# 39657    PFIZER-BIONTECH
# 39658    PFIZER-BIONTECH
# 39659    PFIZER-BIONTECH
# 39660    PFIZER-BIONTECH
# 39661            MODERNA
# 39662            MODERNA
# 39663    PFIZER-BIONTECH
# 39664    PFIZER-BIONTECH
# 39665    PFIZER-BIONTECH
# 39666    PFIZER-BIONTECH
# 39667    PFIZER-BIONTECH
# 39668    PFIZER-BIONTECH
# 39669    PFIZER-BIONTECH
# 39670    PFIZER-BIONTECH
# 39671    PFIZER-BIONTECH
# 39672    PFIZER-BIONTECH
# 39673    PFIZER-BIONTECH
# 39674    PFIZER-BIONTECH
# 39675    PFIZER-BIONTECH
# 39676            MODERNA
# 39677            MODERNA
# 39678    PFIZER-BIONTECH
# 39679    PFIZER-BIONTECH
# 39680    PFIZER-BIONTECH
# 39683            MODERNA
# 39684            MODERNA
# 39685            MODERNA
# 39686    PFIZER-BIONTECH
# 39687    PFIZER-BIONTECH
# 39688    PFIZER-BIONTECH
# 39689    PFIZER-BIONTECH
# 39690    PFIZER-BIONTECH
# 39691    PFIZER-BIONTECH
# 39692    PFIZER-BIONTECH
# 39693            MODERNA
# 39694            MODERNA
# 39695            MODERNA
# 39696    PFIZER-BIONTECH
# 39697    PFIZER-BIONTECH
# 39698    PFIZER-BIONTECH
# 39701    PFIZER-BIONTECH
# 39702    PFIZER-BIONTECH
# 39703    PFIZER-BIONTECH
# 39704    PFIZER-BIONTECH
# 39705    PFIZER-BIONTECH
# 39707            MODERNA
# 39708            MODERNA
# 39709            MODERNA
# 39710            MODERNA
# 39711            MODERNA
# 39712    PFIZER-BIONTECH
# 39713            MODERNA
# 39714            MODERNA
# 39715            MODERNA
# 39716    PFIZER-BIONTECH
# 39717    PFIZER-BIONTECH
# 39718    PFIZER-BIONTECH
# 39719    PFIZER-BIONTECH
# 39720    PFIZER-BIONTECH
# 39721    PFIZER-BIONTECH
# 39722            MODERNA
# 39723            MODERNA
# 39724            MODERNA
# 39725            MODERNA
# 39726            MODERNA
# 39727            MODERNA
# 39730    PFIZER-BIONTECH
# 39731    PFIZER-BIONTECH
# 39734            MODERNA
# 39735            MODERNA
# 39736    PFIZER-BIONTECH
# 39737    PFIZER-BIONTECH
# 39738    PFIZER-BIONTECH
# 39740    PFIZER-BIONTECH
# 39741    PFIZER-BIONTECH
# 39742    PFIZER-BIONTECH
# 39748    PFIZER-BIONTECH
# 39750    PFIZER-BIONTECH
# 39751    PFIZER-BIONTECH
# 39752    PFIZER-BIONTECH
# 39753    PFIZER-BIONTECH
# 39755    PFIZER-BIONTECH
# 39756            MODERNA
# 39757            MODERNA
# 39758            MODERNA
# 39759            MODERNA
# 39760            MODERNA
# 39761            MODERNA
# 39762            MODERNA
# 39763            MODERNA
# 39764    PFIZER-BIONTECH
# 39765    PFIZER-BIONTECH
# 39766    PFIZER-BIONTECH
# 39767    PFIZER-BIONTECH
# 39768    PFIZER-BIONTECH
# 39769    PFIZER-BIONTECH
# 39770    PFIZER-BIONTECH
# 39771    PFIZER-BIONTECH
# 39772    PFIZER-BIONTECH
# 39773    PFIZER-BIONTECH
# 39774    PFIZER-BIONTECH
# 39775    PFIZER-BIONTECH
# 39776            MODERNA
# 39777            MODERNA
# 39778    PFIZER-BIONTECH
# 39779            MODERNA
# 39780            MODERNA
# 39781            MODERNA
# 39782    PFIZER-BIONTECH
# 39783            MODERNA
# 39784            MODERNA
# 39785            MODERNA
# 39786            MODERNA
# 39787            MODERNA
# 39788            MODERNA
# 39789            MODERNA
# 39790            MODERNA
# 39791            MODERNA
# 39792            MODERNA
# 39793            MODERNA
# 39794            MODERNA
# 39795            MODERNA
# 39796            MODERNA
# 39797            MODERNA
# 39798            MODERNA
# 39799            MODERNA
# 39800            MODERNA
# 39801            MODERNA
# 39802            MODERNA
# 39803            MODERNA
# 39804            MODERNA
# 39805            MODERNA
# 39806            MODERNA
# 39807            MODERNA
# 39808            MODERNA
# 39809            MODERNA
# 39810            MODERNA
# 39811            MODERNA
# 39812            MODERNA
# 39813    PFIZER-BIONTECH
# 39814    PFIZER-BIONTECH
# 39815    PFIZER-BIONTECH
# 39816    PFIZER-BIONTECH
# 39817    PFIZER-BIONTECH
# 39818    PFIZER-BIONTECH
# 39819    PFIZER-BIONTECH
# 39820    PFIZER-BIONTECH
# 39821    PFIZER-BIONTECH
# 39822    PFIZER-BIONTECH
# 39823    PFIZER-BIONTECH
# 39824            MODERNA
# 39825            MODERNA
# 39826            MODERNA
# 39827            MODERNA
# 39828            MODERNA
# 39829    PFIZER-BIONTECH
# 39830    PFIZER-BIONTECH
# 39831    PFIZER-BIONTECH
# 39832    PFIZER-BIONTECH
# 39833    PFIZER-BIONTECH
# 39834            MODERNA
# 39835            MODERNA
# 39836            MODERNA
# 39837            MODERNA
# 39840    PFIZER-BIONTECH
# 39841            MODERNA
# 39842            MODERNA
# 39843            MODERNA
# 39844    PFIZER-BIONTECH
# 39845            MODERNA
# 39846            MODERNA
# 39847            MODERNA
# 39848            MODERNA
# 39849            MODERNA
# 39850            MODERNA
# 39851            MODERNA
# 39852    PFIZER-BIONTECH
# 39853    PFIZER-BIONTECH
# 39854    PFIZER-BIONTECH
# 39855    PFIZER-BIONTECH
# 39856    PFIZER-BIONTECH
# 39857            MODERNA
# 39858            MODERNA
# 39859            MODERNA
# 39860    PFIZER-BIONTECH
# 39861    PFIZER-BIONTECH
# 39862            MODERNA
# 39863            MODERNA
# 39864    PFIZER-BIONTECH
# 39865    PFIZER-BIONTECH
# 39866            MODERNA
# 39867            MODERNA
# 39868            MODERNA
# 39869    PFIZER-BIONTECH
# 39870            MODERNA
# 39871            MODERNA
# 39872            MODERNA
# 39873            MODERNA
# 39874            MODERNA
# 39875            MODERNA
# 39876            MODERNA
# 39877            MODERNA
# 39878            MODERNA
# 39879            MODERNA
# 39880    PFIZER-BIONTECH
# 39881    PFIZER-BIONTECH
# 39882            MODERNA
# 39883    PFIZER-BIONTECH
# 39884    PFIZER-BIONTECH
# 39885    PFIZER-BIONTECH
# 39886    PFIZER-BIONTECH
# 39887            MODERNA
# 39888            MODERNA
# 39889            MODERNA
# 39890            MODERNA
# 39891            MODERNA
# 39892            MODERNA
# 39893    PFIZER-BIONTECH
# 39894    PFIZER-BIONTECH
# 39895    PFIZER-BIONTECH
# 39896    PFIZER-BIONTECH
# 39897            MODERNA
# 39898            MODERNA
# 39899            MODERNA
# 39900            MODERNA
# 39901            MODERNA
# 39902            MODERNA
# 39903            MODERNA
# 39904    PFIZER-BIONTECH
# 39905    PFIZER-BIONTECH
# 39906    PFIZER-BIONTECH
# 39907    PFIZER-BIONTECH
# 39908            MODERNA
# 39909            MODERNA
# 39910            MODERNA
# 39911            MODERNA
# 39912    PFIZER-BIONTECH
# 39913    PFIZER-BIONTECH
# 39914            MODERNA
# 39915            MODERNA
# 39916            MODERNA
# 39917            MODERNA
# 39918            MODERNA
# 39919            MODERNA
# 39920    PFIZER-BIONTECH
# 39921    PFIZER-BIONTECH
# 39922            MODERNA
# 39923            MODERNA
# 39924            MODERNA
# 39925            MODERNA
# 39926            MODERNA
# 39927            UNKNOWN
# 39928            UNKNOWN
# 39929            MODERNA
# 39930            MODERNA
# 39931            MODERNA
# 39932            MODERNA
# 39933            MODERNA
# 39934            MODERNA
# 39935    PFIZER-BIONTECH
# 39937    PFIZER-BIONTECH
# 39938    PFIZER-BIONTECH
# 39939    PFIZER-BIONTECH
# 39940    PFIZER-BIONTECH
# 39941    PFIZER-BIONTECH
# 39942    PFIZER-BIONTECH
# 39943    PFIZER-BIONTECH
# 39944    PFIZER-BIONTECH
# 39945    PFIZER-BIONTECH
# 39946    PFIZER-BIONTECH
# 39947    PFIZER-BIONTECH
# 39948    PFIZER-BIONTECH
# 39949    PFIZER-BIONTECH
# 39950    PFIZER-BIONTECH
# 39951    PFIZER-BIONTECH
# 39952    PFIZER-BIONTECH
# 39953    PFIZER-BIONTECH
# 39954    PFIZER-BIONTECH
# 39955    PFIZER-BIONTECH
# 39956    PFIZER-BIONTECH
# 39957    PFIZER-BIONTECH
# 39958    PFIZER-BIONTECH
# 39959    PFIZER-BIONTECH
# 39960    PFIZER-BIONTECH
# 39965    PFIZER-BIONTECH
# 39966    PFIZER-BIONTECH
# 39967    PFIZER-BIONTECH
# 39971    PFIZER-BIONTECH
# 39972    PFIZER-BIONTECH
# 39973    PFIZER-BIONTECH
# 39974    PFIZER-BIONTECH
# 39975    PFIZER-BIONTECH
# 39977    PFIZER-BIONTECH
# 39978    PFIZER-BIONTECH
# 39979    PFIZER-BIONTECH
# 39981    PFIZER-BIONTECH
# 39982    PFIZER-BIONTECH
# 39983    PFIZER-BIONTECH
# 39984            MODERNA
# 39985    PFIZER-BIONTECH
# 39986            MODERNA
# 39987    PFIZER-BIONTECH
# 39988            MODERNA
# 39989    PFIZER-BIONTECH
# 39990    PFIZER-BIONTECH
# 39991    PFIZER-BIONTECH
# 39992    PFIZER-BIONTECH
# 39993    PFIZER-BIONTECH
# 39994    PFIZER-BIONTECH
# 39996    PFIZER-BIONTECH
# 39997    PFIZER-BIONTECH
# 39998    PFIZER-BIONTECH
# 40004    PFIZER-BIONTECH
# 40005    PFIZER-BIONTECH
# 40008    PFIZER-BIONTECH
# 40009    PFIZER-BIONTECH
# 40010    PFIZER-BIONTECH
# 40011            MODERNA
# 40012    PFIZER-BIONTECH
# 40013    PFIZER-BIONTECH
# 40014    PFIZER-BIONTECH
# 40017    PFIZER-BIONTECH
# 40018    PFIZER-BIONTECH
# 40019            MODERNA
# 40020            MODERNA
# 40021            MODERNA
# 40022            MODERNA
# 40023            MODERNA
# 40024            MODERNA
# 40025            MODERNA
# 40026            MODERNA
# 40027            MODERNA
# 40028            MODERNA
# 40029    PFIZER-BIONTECH
# 40030    PFIZER-BIONTECH
# 40031    PFIZER-BIONTECH
# 40032    PFIZER-BIONTECH
# 40033    PFIZER-BIONTECH
# 40034    PFIZER-BIONTECH
# 40035            MODERNA
# 40036            MODERNA
# 40037            MODERNA
# 40038            MODERNA
# 40039            MODERNA
# 40040            MODERNA
# 40041            MODERNA
# 40042    PFIZER-BIONTECH
# 40043    PFIZER-BIONTECH
# 40044    PFIZER-BIONTECH
# 40045    PFIZER-BIONTECH
# 40046    PFIZER-BIONTECH
# 40047            MODERNA
# 40048    PFIZER-BIONTECH
# 40049    PFIZER-BIONTECH
# 40050    PFIZER-BIONTECH
# 40051    PFIZER-BIONTECH
# 40052    PFIZER-BIONTECH
# 40053    PFIZER-BIONTECH
# 40054            MODERNA
# 40055            MODERNA
# 40056            MODERNA
# 40057            MODERNA
# 40058            MODERNA
# 40059            MODERNA
# 40060    PFIZER-BIONTECH
# 40061            MODERNA
# 40062            MODERNA
# 40063            MODERNA
# 40064            MODERNA
# 40065            MODERNA
# 40066    PFIZER-BIONTECH
# 40067            MODERNA
# 40068            MODERNA
# 40069            MODERNA
# 40070            MODERNA
# 40071            MODERNA
# 40072            MODERNA
# 40073            MODERNA
# 40074            MODERNA
# 40075            MODERNA
# 40076            MODERNA
# 40077            MODERNA
# 40078            MODERNA
# 40079            MODERNA
# 40080            MODERNA
# 40081            MODERNA
# 40082            MODERNA
# 40083            MODERNA
# 40084            MODERNA
# 40085            MODERNA
# 40086            MODERNA
# 40087    PFIZER-BIONTECH
# 40088    PFIZER-BIONTECH
# 40089            MODERNA
# 40090            MODERNA
# 40091    PFIZER-BIONTECH
# 40092            MODERNA
# 40093    PFIZER-BIONTECH
# 40094    PFIZER-BIONTECH
# 40095    PFIZER-BIONTECH
# 40096    PFIZER-BIONTECH
# 40097    PFIZER-BIONTECH
# 40098            MODERNA
# 40099    PFIZER-BIONTECH
# 40101            MODERNA
# 40102            MODERNA
# 40103    PFIZER-BIONTECH
# 40104    PFIZER-BIONTECH
# 40105    PFIZER-BIONTECH
# 40106    PFIZER-BIONTECH
# 40107            MODERNA
# 40108    PFIZER-BIONTECH
# 40109    PFIZER-BIONTECH
# 40110    PFIZER-BIONTECH
# 40111            MODERNA
# 40112    PFIZER-BIONTECH
# 40113            MODERNA
# 40114            MODERNA
# 40115            MODERNA
# 40116            MODERNA
# 40117            MODERNA
# 40118            MODERNA
# 40119            MODERNA
# 40120    PFIZER-BIONTECH
# 40121    PFIZER-BIONTECH
# 40122    PFIZER-BIONTECH
# 40123    PFIZER-BIONTECH
# 40124    PFIZER-BIONTECH
# 40125    PFIZER-BIONTECH
# 40126    PFIZER-BIONTECH
# 40127    PFIZER-BIONTECH
# 40128            MODERNA
# 40129            MODERNA
# 40130            MODERNA
# 40131            MODERNA
# 40132            MODERNA
# 40133            MODERNA
# 40134            MODERNA
# 40135    PFIZER-BIONTECH
# 40136    PFIZER-BIONTECH
# 40137    PFIZER-BIONTECH
# 40138    PFIZER-BIONTECH
# 40139    PFIZER-BIONTECH
# 40140    PFIZER-BIONTECH
# 40141            MODERNA
# 40142            MODERNA
# 40143            MODERNA
# 40144            MODERNA
# 40145            MODERNA
# 40146            MODERNA
# 40147            MODERNA
# 40148            MODERNA
# 40149            MODERNA
# 40150            MODERNA
# 40151    PFIZER-BIONTECH
# 40152    PFIZER-BIONTECH
# 40153            MODERNA
# 40154    PFIZER-BIONTECH
# 40155    PFIZER-BIONTECH
# 40156    PFIZER-BIONTECH
# 40157    PFIZER-BIONTECH
# 40158            MODERNA
# 40159            MODERNA
# 40160            MODERNA
# 40161            MODERNA
# 40162            MODERNA
# 40163            MODERNA
# 40164    PFIZER-BIONTECH
# 40165    PFIZER-BIONTECH
# 40166            MODERNA
# 40167            MODERNA
# 40168    PFIZER-BIONTECH
# 40169    PFIZER-BIONTECH
# 40170    PFIZER-BIONTECH
# 40171    PFIZER-BIONTECH
# 40172    PFIZER-BIONTECH
# 40173    PFIZER-BIONTECH
# 40174    PFIZER-BIONTECH
# 40175    PFIZER-BIONTECH
# 40176    PFIZER-BIONTECH
# 40177    PFIZER-BIONTECH
# 40178    PFIZER-BIONTECH
# 40179    PFIZER-BIONTECH
# 40180    PFIZER-BIONTECH
# 40181    PFIZER-BIONTECH
# 40182    PFIZER-BIONTECH
# 40183    PFIZER-BIONTECH
# 40184            MODERNA
# 40185            MODERNA
# 40186            MODERNA
# 40187            MODERNA
# 40188            MODERNA
# 40189            MODERNA
# 40190            MODERNA
# 40191            MODERNA
# 40192            MODERNA
# 40193    PFIZER-BIONTECH
# 40194    PFIZER-BIONTECH
# 40195    PFIZER-BIONTECH
# 40196    PFIZER-BIONTECH
# 40197    PFIZER-BIONTECH
# 40198            MODERNA
# 40199            MODERNA
# 40200    PFIZER-BIONTECH
# 40201            MODERNA
# 40202    PFIZER-BIONTECH
# 40203            MODERNA
# 40204            MODERNA
# 40205            MODERNA
# 40206    PFIZER-BIONTECH
# 40207    PFIZER-BIONTECH
# 40208    PFIZER-BIONTECH
# 40209    PFIZER-BIONTECH
# 40210    PFIZER-BIONTECH
# 40211            MODERNA
# 40212            MODERNA
# 40213            MODERNA
# 40214            MODERNA
# 40215            MODERNA
# 40216            MODERNA
# 40217    PFIZER-BIONTECH
# 40218    PFIZER-BIONTECH
# 40219    PFIZER-BIONTECH
# 40220    PFIZER-BIONTECH
# 40221    PFIZER-BIONTECH
# 40222    PFIZER-BIONTECH
# 40223    PFIZER-BIONTECH
# 40224    PFIZER-BIONTECH
# 40225    PFIZER-BIONTECH
# 40226    PFIZER-BIONTECH
# 40227    PFIZER-BIONTECH
# 40228    PFIZER-BIONTECH
# 40229    PFIZER-BIONTECH
# 40231            MODERNA
# 40232            MODERNA
# 40237    PFIZER-BIONTECH
# 40238    PFIZER-BIONTECH
# 40239    PFIZER-BIONTECH
# 40240    PFIZER-BIONTECH
# 40246    PFIZER-BIONTECH
# Name: vax_name, dtype: object

# %%
#Convert vax_name column from object to numerical values for unsupervised model, representing each vaccine (Moderna, Pfizer, Janssen)
def change_vax(vax_name):
    if vax_name == "MODERNA":
        return 1
    elif vax_name == "PFIZER-BIONTECH":
        return 2
    elif vax_name == "JANSSEN":
        return 3
    else:
        return 4
vaers_UML["vax_name"] = vaers_UML["vax_name"].apply(change_vax)
vaers_UML.head(50)
# Out:
#    vaers_id  age_yrs  sex  died  vax_name
# 2   1000003     29.0    2     1         2
# 4   1000007     53.0    1     1         2
# 8   1000021     62.0    2     1         2
# 10  1000036     38.0    1     1         2
# 13  1000046     86.0    1     1         2
# 14  1000051     70.0    2     1         2
# 15  1000051     70.0    2     1         2
# 16  1000051     70.0    2     1         2
# 19  1000074     80.0    2     1         2
# 20  1000074     80.0    2     1         2
# 22  1000082     70.0    2     1         2
# 24  1000103     54.0    1     1         2
# 25  1000103     54.0    1     1         2
# 29  1000122     36.0    2     1         2
# 30  1000124     73.0    2     1         2
# 31  1000124     73.0    2     1         2
# 32  1000124     73.0    2     1         2
# 34  1000134     19.0    2     1         2
# 35  1000134     19.0    2     1         2
# 37  1000147     72.0    2     1         2
# 38  1000149     54.0    2     1         2
# 40  1000159     65.0    1     1         2
# 42  1000165     39.0    1     1         1
# 44  1000169     50.0    2     1         1
# 45  1000170     73.0    1     1         2
# 46  1000172     55.0    2     1         1
# 48  1000175     38.0    2     1         1
# 51  1000191     47.0    2     1         2
# 54  1000199     56.0    1     1         2
# 56  1000206     49.0    2     1         2
# 57  1000206     49.0    2     1         2
# 58  1000207     32.0    2     1         2
# 59  1000209     49.0    2     1         2
# 60  1000210     34.0    2     1         2
# 61  1000212     38.0    1     1         2
# 62  1000212     38.0    1     1         2
# 63  1000213     52.0    2     1         2
# 64  1000213     52.0    2     1         2
# 66  1000215     45.0    2     1         2
# 67  1000216     81.0    1     1         2
# 68  1000216     81.0    1     1         2
# 69  1000217     94.0    2     1         2
# 70  1000217     94.0    2     1         2
# 71  1000218     87.0    2     1         2
# 72  1000218     87.0    2     1         2
# 73  1000219     67.0    2     1         2
# 74  1000219     67.0    2     1         2
# 75  1000226     86.0    2     2         2
# 76  1000227     67.0    1     1         2
# 77  1000228     40.0    1     2         2

# %% [markdown]
# CONDUCT UNSUPERVISED MODEL

# %%
#Use REGEX to filter for only COVID19 KEEP FOR FUTURE USE
vax_names = vaers_UML['vax_name']
vax_names.str.contains(regex, flags=re.IGNORECASE).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-a31d237c1613> in <module>
#       1 #Use REGEX to filter for only COVID19 KEEP FOR FUTURE USE
#       2 vax_names = vaers_UML['vax_name']
# ----> 3 vax_names.str.contains(regex, flags=re.IGNORECASE).sum()
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
#Remove all values in vax_name that do not include 'COVID19' using REGEX, in order to select only the top three unique values in 
#vax_name. Therefore the only three vaccines will be three covid19 vaccines; moderna, pfizer-biontech, and janssen. 
regex = r' \b(\w*COVID19\w*)\b'
